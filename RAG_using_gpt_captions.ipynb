# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 71.4 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 12.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 13.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
pip install -U bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 46.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
import torch
import numpy as np
import faiss
from PIL import Image
import pandas as pd
from tqdm.auto import tqdm

# 1) Models for embeddings
from transformers import CLIPModel, CLIPProcessor
from sentence_transformers import SentenceTransformer

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
#
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_pickle("/content/drive/MyDrive/patchcamelyon_captions_df_final_final_new_new.pkl")

# %%
clip_model     = CLIPModel.from_pretrained("openai/clip-vit-large-patch14").eval().to("cuda")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")

# %%
text_embedder = SentenceTransformer("all-MiniLM-L6-v2")

# %%
img_embs = []
for img in tqdm(df["image"], desc="Embedding images"):
    inputs = clip_processor(images=img, return_tensors="pt").to("cuda")
    with torch.no_grad():
        feat = clip_model.get_image_features(**inputs)  # (1, 768)
    feat = feat / feat.norm(dim=-1, keepdim=True)
    img_embs.append(feat.cpu().numpy())

img_embs = np.vstack(img_embs)  # (N, 768)

txt_embs = text_embedder.encode(
    df["caption"].tolist(),
    batch_size=64,
    show_progress_bar=True,
    convert_to_numpy=True,
)
# Out:
# Embedding images:   0%|          | 0/14311 [00:00<?, ?it/s]
# Batches:   0%|          | 0/224 [00:00<?, ?it/s]

# %%
faiss.normalize_L2(txt_embs)

# %%
combined = np.concatenate([img_embs, txt_embs], axis=1)

# %%
faiss.normalize_L2(combined)

# %%
d = combined.shape[1]                  # 1152
index = faiss.IndexFlatIP(d)          # inner-product similarity
index.add(combined)                   # add all N vectors

os.makedirs("rag_index", exist_ok=True)
faiss.write_index(index, "/content/drive/MyDrive/pcam_rag_index_withlables_new/caption_image_index.faiss")

# Save a mapping from row‐idx → metadata
# so you can look up the original caption/image_id later:
df[["caption"]].to_json(
    "rag_index/metadata.jsonl",
    orient="records",
    lines=True
)

# %%
import os, json

# assume df has columns: "caption", "label"
BASE_PATH = "/content/drive/MyDrive/pcam_rag_index_withlables_new"
os.makedirs(BASE_PATH, exist_ok=True)

# Build the metadata with labels
docs = [
    {
        "id": idx,
        "caption": cap,
        "label": int(lab)
    }
    for idx, (cap, lab) in enumerate(zip(df["caption"], df["label"]))
]

# Save it out as JSON‐lines
meta_path = os.path.join(BASE_PATH, "metadata.jsonl")
with open(meta_path, "w") as f:
    for doc in docs:
        f.write(json.dumps(doc) + "\n")
print("Saved metadata with labels to", meta_path)
# Out:
# Saved metadata with labels to /content/drive/MyDrive/pcam_rag_index_withlables_new/metadata.jsonl

# %% [markdown]
# Reading faiss

# %%
from itertools import islice
from datasets import load_dataset

# %%
streamed_dataset = load_dataset("1aurent/PatchCamelyon", split="test", streaming=True)
test_samples = list(islice(streamed_dataset, 200))

# %%
test_images = [item['image'] for item in test_samples]  # PIL Images
test_labels = [int(item['label']) for item in test_samples]  # convert bool to int (0 or 1)

# %%
import os
import json
import torch
import torch.nn as nn
import pandas as pd
from itertools import islice
from datasets import load_dataset
from PIL import Image
from transformers import (
    GPT2Tokenizer,
    GPT2LMHeadModel,
    BitsAndBytesConfig,
    CLIPProcessor,
    CLIPModel,
)
from peft import PeftModel

# ─── 0.  Configuration ─────────────────────────────────────────
OUT_DIR     = "/content/drive/MyDrive/gpt2_clip_histopath_lora_new"
DEVICE      = "cuda"
PREFIX_LEN  = 10
CLIP_DIM    = 768
EMBED_DIM   = 768
NUM_SAMPLES = 500    # set to None to process the whole split

# ─── 1.  Reload tokenizer (must have been saved after training) ─
tokenizer = GPT2Tokenizer.from_pretrained(OUT_DIR)
tokenizer.pad_token = tokenizer.eos_token

# ─── 2.  Load fine-tuned GPT-2 + LoRA adapter in 8-bit ─────────
bnb8 = BitsAndBytesConfig(load_in_8bit=True)
base_gpt2 = GPT2LMHeadModel.from_pretrained(
    "gpt2",
    quantization_config=bnb8,
    device_map="auto",
    torch_dtype=torch.float16,
)
gpt2_lora = (
    PeftModel.from_pretrained(base_gpt2, OUT_DIR)
    .to(DEVICE)
    .eval()
)

# ─── 3.  Rebuild & load the mapper MLP ────────────────────────
class Clip2Prefix(nn.Module):
    def __init__(self, clip_dim, embed_dim, prefix_len):
        super().__init__()
        hidden = embed_dim * prefix_len // 2
        self.fc = nn.Sequential(
            nn.Linear(clip_dim, hidden),
            nn.Tanh(),
            nn.Linear(hidden, embed_dim * prefix_len),
        )
        self.prefix_len = prefix_len
        self.embed_dim  = embed_dim

    def forward(self, clip):
        return self.fc(clip).view(-1, self.prefix_len, self.embed_dim)

mapper = Clip2Prefix(CLIP_DIM, EMBED_DIM, PREFIX_LEN).to(DEVICE)
mapper.load_state_dict(
    torch.load(os.path.join(OUT_DIR, "mapper.pt"), map_location=DEVICE)
)
mapper.eval()

# ─── 4.  Define inference wrapper with correct dtype & mask ────
class ClipCaptionModel(nn.Module):
    def __init__(self, gpt2: PeftModel, mapper: nn.Module, prefix_len: int, pad_token_id: int):
        super().__init__()
        self.gpt2        = gpt2
        self.mapper      = mapper
        self.prefix_len  = prefix_len
        self.pad_token_id = pad_token_id

    @torch.no_grad()
    def generate_caption(self, clip_emb: torch.Tensor, **gen_kwargs):
        # clip_emb: (1, CLIP_DIM) float32
        # 1) map to prefix embeddings, cast to gpt2 dtype
        prefix = self.mapper(clip_emb.to(self.gpt2.device))
        prefix = prefix.to(self.gpt2.dtype)  # e.g. float16

        # 2) build attention mask for the prefix
        batch_size = prefix.size(0)
        prefix_mask = torch.ones(
            batch_size, self.prefix_len,
            dtype=torch.long,
            device=self.gpt2.device
        )

        # 3) generate with mask and pad_token_id
        return self.gpt2.generate(
            inputs_embeds=prefix,
            attention_mask=prefix_mask,
            pad_token_id=self.pad_token_id,
            **gen_kwargs
        )

caption_model = ClipCaptionModel(
    gpt2_lora,
    mapper,
    prefix_len=PREFIX_LEN,
    pad_token_id=tokenizer.pad_token_id
)

# ─── 5.  Load CLIP model & processor ───────────────────────────
clip_model     = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")\
                        .to(DEVICE).eval()
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")

# ─── 6.  Load PCam dataset ─────────────────────────────────────
ds = load_dataset("1aurent/PatchCamelyon", split="test", streaming=False)

# ─── 7.  Inference loop ────────────────────────────────────────
results = []
for ex in islice(ds, NUM_SAMPLES):
    img, label = ex["image"], ex["label"]

    # a) CLIP embed
    clip_inputs = clip_processor(images=img, return_tensors="pt").to(DEVICE)
    with torch.no_grad():
        emb = clip_model.get_image_features(**clip_inputs)
        emb = emb / emb.norm(p=2, dim=-1, keepdim=True)

    # b) Generate caption
    gen_ids = caption_model.generate_caption(
        emb,
        max_new_tokens=64,
        do_sample=True,
        temperature=0.9,
        top_p=0.9,
    )
    caption = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    # c) Print & store
    print(f"Label={label} → {caption}")
    results.append({"image": img, "label": label, "caption": caption})

# ─── 8.  Build DataFrame ────────────────────────────────────────
df = pd.DataFrame(results)
print(df.head())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00000-of-00013-4717c3cf92578c96.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00001-of-00013-549914845b4273b1.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00002-of-00013-a859720d3cfcebdf.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00003-of-00013-a70975735603ee91.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00004-of-00013-f3cb3678324a5346.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00005-of-00013-959ba247c1881dc0.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00006-of-00013-318f5c6d89fc04ef.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00007-of-00013-c8a1a9cf7273420c.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00008-of-00013-3d4f66c19471ed0a.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00009-of-00013-867b6df30133f28e.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00010-of-00013-abf99d3df1f77818.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00011-of-00013-e929006353f3ae95.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00012-of-00013-73b855ce7d233beb.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00000-of-00002-0e1a29e0620125c6.parquet:   0%|          | 0.00/383M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00001-of-00002-aad8011eb887c9d9.parquet:   0%|          | 0.00/385M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00000-of-00002-bb04e6313f58efa0.parquet:   0%|          | 0.00/376M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# (…)-00001-of-00002-3bfa172e8818685a.parquet:   0%|          | 0.00/375M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/262144 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/32768 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/32768 [00:00<?, ? examples/s]
# Label=False → enoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - In the superficial epithelium, tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed. Some tumor cells exhibit marked fusion or clustering. tumor cells exhibit a fusion-like shape and exhibit hyperchromatism.
# Label=False → enocarcinoma - Tumor tissue consisting of cord-like or small irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar and show nucleus.
# Label=True → enocarcinoma - On the superficial epithelium, tumor tissue consisting of medium-sized and irregular glandular ducts infiltrating is observed. Well differentiated tubular adenocarcinoma
# Label=True →  solid type - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → et inflammas adenocarcinoma - Tumor tissue consisting of large glandular ducts partially fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → enoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized irregular ducts is observed. Well differentiated tubular adenocarcinoma.
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. tumor tissue consisting of medium-sized and irregular glandular ducts showing
# Label=True → enocarcinoma - Tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False →  cell growth is observed in the superficial epithelium, showing a large sheet-like shape, and some tumor tissue infiltrates with small irregular ducts. Annex cells exhibit atypical nuclei with large nuclei and a large sheet-like shape. Well differentiated tubular adenocarcinoma
# Label=True →  solid type - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False →  differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Some tumor cells exhibit large nucleus, but
# Label=True →  cell carcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and show a dense columnar shape.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells exhibit dense metasten
# Label=True →  differentiated adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar, with
# Label=True →  to form solid nucleus. Tumor tissue consisting of solid or irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → enoma
# Label=False → enoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Poorly differentiated adenocarcinoma, non-solid type or moderately differentiated tubular adenocarcinoma
# Label=False → apillary adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False →  - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=False → et adenocarcinoma - Tumor cells with atypical nuclei forming dense vesicles or small irregular atypical ducts and proliferating in response to tumor necrosis.
# Label=True →  cell carcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells exhibit a dense columnar structure and are densely
# Label=True → enocarcinoma - Tumor tissue that infiltrates by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Poorly differentiated adenocarcinoma
# Label=True → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. tumor cells with atypical nuclei exhibit atypical ducts that are highly columnar and columnar. Nuclear cord cell type Tum
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and exhibit a large nuclei.
# Label=True → enoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Adenoma
# Label=True → enocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells exhibit a large number of nuclei and
# Label=True → in structure - Tumor tissue consisting of large, irregular glandular ducts fused and infiltrated is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → enocarcinoma - On the superficial epithelium, tumor tissue consisting of medium-sized and irregular glandular ducts infiltrating is observed.
# Label=True → apetocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Papillary adenocarcinoma
# Label=True → enocarcinoma - Tumor tissue consisting of cord-like or small irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Large number of tumor cells exhibit cord-like or small
# Label=True →  adenocarcinoma - Tumor tissue that grows in a cell-like fashion, and infiltrates with a high number of nuclei is observed.
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and are densely columnar. Adenocarcinoma
# Label=False →  Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are heterogeneous.
# Label=False →  - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. tumor tissue cells are highly columnar, large, large club-shaped. Large tumor cell types show oligosapotropic nuclei, and are associated with tumor cell aggregation. Tum
# Label=True →  adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Adenocarcinoma
# Label=False →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. moderately differentiated tubular adenocarcin
# Label=True → etitis - Tumor tissue consisting of medium-sized and irregular glandular ducts infiltrating is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally.
# Label=True →  adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Adenocarcinoma.
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of a large sheet-like nucleus and a small irregular duct is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Well differentiated tubular adenoc
# Label=True →  - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. In the superficial epithelium, tumor tissue that invades by forming medium-sized to small ducts is observed.
# Label=True →  tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed infiltrating in the superficial epithelium. Papilium
# Label=True → enoma - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar, with nuclei aligned basol
# Label=True → enocarcinoma - Tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar and show nuclei aligned basolaterally and polarized.
# Label=True →  adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells are highly columnar, large and diffuse.
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of large, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False →  Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are oligosaplet cell type or small irregular glandular ducts
# Label=False →  differentiated tubular adenocarcinoma - Tumor tissue consisting of large, irregular glandular ducts partially fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  adenocarcinoma - On the superficial epithelium, tumor tissue that invades by forming medium-sized irregular ducts is observed. Adenocarcinoma
# Label=True →  Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Poorly differentiated adenocarcinoma, non-solid type or moderately differentiated tubular adenocarcinoma
# Label=False → enoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. moderately differentiated tubular adenocarcinoma.
# Label=False → atinous tumor tissue that proliferates with a large sheet-like shape or small irregular ducts is observed.
# Label=True →  Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar with nuclei aligned basolaterally and
# Label=True →  solid type - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False →  adenocarcinoma - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False →  ductal formation shows a dense, tubular shape and infiltrates. Annex cells exhibit a polygonal pattern and diffusely show tumor tissue infiltrating. Tumor cells are highly columnar and are polarized.
# Label=False →  - Tumor tissue consisting of medium-sized and irregular ducts infiltrating is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. tumor tissue Tumor cells are highly columnar, with nuclei aligned basol
# Label=False →  - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar and exhibit a nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue that infiltrates by forming medium-sized irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells exhibit a large columnar shape.
# Label=True → enet alveolar tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Adenotenin cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → atinocytes are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Moderately differentiated adenocarcinoma.
# Label=True →  adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. tumor tissue consisting of solid or irregular glandular ducts showing solid growth
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=True → in Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells exhibit a large number of nuclei, and are heterogeneous. tumor tissue are highly columnar, and are associated with tumor cell aggregation. tumor cells exhibit a high
# Label=True → enoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized irregular ducts is observed. Nuclear glandular glandular ducts fuse with each other and infiltrate. Nuclear glandular ducts diffusely and infiltrate
# Label=False →
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells exhibit a large columnar shape,
# Label=True → etoid infiltrating tumor tissue showing a large sheet-like shape and growing solidified. Well differentiated tubular adenocarcinoma
# Label=True → et al, solid type - The superficial epithelium shows a large sheet-like shape, and tumor tissue infiltrating with small irregular ducts shows solid type. Well differentiated tubular adenocarcinoma
# Label=True →  - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and show nuclei aligned basolaterally.
# Label=True →  cell type - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=False →  differentiated tubular adenocarcinoma - On the superficial epithelium, tumor tissue consisting of medium-sized and irregular glandular ducts infiltrating is observed. moderately differentiated tubular adenocarcinoma
# Label=True →  solid type - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Adenotum moderately differentiated tubular adenocarcinoma
# Label=True →  differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Poorly differentiated adenocarcinoma.
# Label=True →  - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar, with nuclei aligned bas
# Label=True →  Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized
# Label=True → enet polygonal nucleus
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → -type or non-incomoriant
# Label=True → atinoma - Tumor tissue consisting of large sheet-like or irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True →  adenocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Adenocarcinoma (well differentiated tubular adenocarcinoma, non-solid type tumor type)
# Label=True → enoma - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → in Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  adenocarcinoma
# Label=False → etto superficial adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → etaceous glandular ducts are formed with large, irregular ducts, and are highly columnar, with nuclei aligned fused at a high frequency. moderately differentiated tubular adenocarcinoma
# Label=False → enoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Tumor cells are polychromatin with large dense columnar nucleus and
# Label=True →  - Tumor tissue consisting of large, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → atinocytes are highly columnar, with nuclei aligned in series and small irregular ducts forming. Some are fused with adenocarcinoma and show fused papillary ductal formation. Adenocarcinoma
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts fused is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Large tumor cells show an alveolar shape and
# Label=False → enoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are densely columnar and highly columnar.
# Label=False → enigment in the superficial epithelium shows a highly irregular glandular duct, and in some cases, the glandular ducts fuse with each other and infiltrate. Large tumor cells show a large papillary structure. Well differentiated tubular adenocarcinoma.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are densely columnar, with nuclei aligned bas
# Label=True →  differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. tumor cells exhibit a large nucleus and are highly columnar. Large tumor cells exhibit fused solid alveolar lesions.
# Label=True → enocarcinoma - On the superficial epithelium, tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed. Well differentiated tubular adenocarcinoma
# Label=True →  - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar and show fused fused nuclei.
# Label=True → atinoma - Tumor tissue that infiltrates the epithelium by forming medium-sized to small, irregular ducts is observed. Tumor cells exhibit nuclei that are fused to each other and infiltrate.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=False → atinous epithelial cells with atypical nuclei forming large ducts and forming atypical fusion ducts. Large tumor cells with atypical nuclei forming large atypical fusion ducts.
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Papillary adenocarcinoma
# Label=False → enoma with medium to small irregular gland ducts fused and infiltrated. Moderately show not cells with large irregular gland ducts fused and infiltrated.
# Label=False →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - On the superficial epithelium, tumor tissue consisting of medium-sized and irregular glandular ducts infiltrating is observed. tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → et adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells are highly columnar, and are associated with chromatin aggregation. Tumor cells exhibit high nuclei, and are associated with
# Label=False → enoma
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Poorly differentiated adenocarcinoma, non-solid type or moderately differentiated tubular adenocarcinoma
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False → atinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True →  Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. tumor cells exhibit a large columnar shape and are highly columnar.
# Label=True → apillary adenocarcinoma
# Label=True →  - The superficial epithelium shows a large sheet-like shape, and some tumor tissue infiltrates with small irregular ducts. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=False → et adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed.
# Label=False → etes, solid type - Atypical epithelium that infiltrate and proliferate with small irregular ducts is observed. Papillary ducts show solid alveolar or elliptical structures and show a fused duct.
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=True → enoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and show nuclei aligned basolaterally and polarized.
# Label=True →  solid type - The superficial epithelium shows large sheet-like shape, and some tumor tissue infiltrates with small irregular ducts. Moderately differentiated adenocarcinoma
# Label=False → et adenocarcinoma - In the superficial epithelium, tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed. tumor cells with atypical nuclei exhibit highly vesicle-like nuclei.
# Label=True →  cell adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar,
# Label=False → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. tumor cells are highly columnar with nuclei aligned basolater
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. tumor cells with atypical nuclei are highly columnar and exhibit high nuclei.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False → etoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular fusion is observed in the superficial epithelium. Well differentiated tubular adenocarcinoma
# Label=True →  differentiated tubular adenocarcinoma
# Label=True →  - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=True →  cell proliferation in which medium to small irregular gland ducts fuse with each other and infiltrate the gland ducts. Well differentiated tubular adenocarcinoma
# Label=True → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Adenocarcinoma
# Label=False →  Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar and columnar, with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar and columnar.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and exhibit nuclei aligned basolaterally and polarized. tumor cells exhibit atypical morphology.
# Label=False → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=False →  differentiated adenocarcinoma
# Label=False → enocarcinoma - Tumor cells are large, highly columnar, large glandular ducts, and are associated with chromatin aggregation. Well differentiated tubular adenocarcinoma.
# Label=False → apillary adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcin
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → in combination of solid type or small irregular glandular ducts fused and infiltrated is observed. Well differentiated tubular adenocarcinoma
# Label=True →  cell adenocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → enocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells are heterogeneous, with nuclei aligned basolaterally and polarized.
# Label=False →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells are densely column
# Label=False → enocarcinoma - On the superficial epithelium, tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed.
# Label=False → aparoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Paparoma.
# Label=True → atinoma - Tumor cells with atypical nuclei forming atypical ducts and proliferating in concert with each other. Tumor cells with atypical nuclei forming atypical ducts and proliferating in concert with each other.
# ...
# Label=False → enoma - Tumor cells are large, highly columnar, large glandular ducts, and are associated with tumor tissue aggregation. Tumor cells are highly columnar, highly columnar, and are associated with cord cord cord fusion.
# Label=True → atum, solid type - The superficial epithelium shows a large sheet-like shape, and some tumor tissue infiltrates with small irregular ducts. moderately differentiated tubular adenocarcinoma.
# Label=True → et adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells exhibit a large nuclei, and are associated with chromatin aggregation. Well differentiated tubular adenocarcinoma.
# Label=True → enocarcinoma - Tumor tissue consisting of cord-like or large, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → atinous cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells are highly columnar, highly columnar, and are associated with chromatin aggregation. Tumor cells exhibit a nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - On the superficial epithelium, tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed. Large tumor cells exhibit large alveolar lesions and hyperchromatism.
# Label=False → et infarctis tissue that grows and shrinks with increasing number of medium-sized irregular ducts infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  cell infiltrating tumor tissue is observed in which medium-sized irregular gland ducts fuse with each other and infiltrate.
# Label=True → in Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → apillary adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Tumor cells exhibit a large number of nuclei and are highly columnar. Papillary adenocarcinoma
# Label=False → atinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed infiltrating. tumor cells are highly columnar and show nuclei aligned basolaterally and polarized. Tumor cells are highly columnar and show glandular ducts fused and polarized.
# Label=False → atinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts infiltrating is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False → enocarcinoma
# Label=True → enet - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → enoma - Tumor tissue consisting of medium-sized irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → enoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=False → et adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Papillary epithelium shows nuclear villus formation. Well differentiated tubular adenocarcinoma.
# Label=True →  cell type - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True →  - Tumor tissue consisting of medium-sized and irregular ducts infiltrating in the superficial epithelium is observed. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. tumor cells exhibit a large number of nuclei. Tumor cells are highly columnar with nucle
# Label=True → etes with atypical nuclei forming large, irregular atypical ducts and growing in concert. Nuclear Insulae with atypical nuclei forming atypical ducts and growing in concert.
# Label=True → in structure and proliferation is observed in the superficial epithelium, showing a large sheet-like shape. Some tumor tissue infiltrates with small irregular ducts. Some tumor tissue show small tumor-like tumor cells and some tumor show a large tumor-like shape. Tumor cells show dense ductal formation and proliferation
# Label=True →  adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Adenocarcinoma
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts infiltrating in the superficial epithelium is observed.
# Label=True → atinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Poorly differentiated adenocarcinoma, non-solid type or moderately differentiated tubular adenocarcinoma, solid type or moderately differentiated tubular aden
# Label=True →  differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Well differentiated tubular adenocarcinoma.
# Label=False → atinitis - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Some tumor cells show a large, irregular glandular ductal structure and are
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium.
# Label=True → in Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Tumor cells exhibit a large number of nuclei, and are densely columnar.
# Label=True → enoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. tumor cells exhibit a large large, irregular glandular duct, and some tumor
# Label=True → et infarct formation showing diffuse fusion and fusion of large irregular ducts with small irregular ducts infiltrating shows solid or irregular ducts forming solid or irregular ducts.
# Label=False →  solid type - Tumor tissue consisting of cord-like or small, irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Moderately differentiated adenocarcinoma.
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → apillary adenocarcinoma - Tumor cells are large, highly columnar, large club-shaped nuclei, and are associated with chromatin aggregation. Nuclear insubliferation is associated with tumor tissue aggregation.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Nuclear localization
# Label=True →  differentiated adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  to moderately differentiated tubular adenocarcinoma - In the superficial epithelium, tumor tissue consisting of large irregular glandular ducts partially fused and infiltrated is observed. Poorly differentiated adenocarcinoma, non-solid type or moderately differentiated tubular adenocarcinoma
# Label=True →  differentiated adenocarcinoma - From the superficial epithelium to the muscularis mucosae, tumor tissue consisting of medium-sized and irregular glandular ducts infiltrating is observed.
# Label=True →  cell growth in which a large sheet of medium-sized irregular gland ducts fuse with each other and infiltrate.
# Label=False → et infrudinoma - Tumor tissue consisting of medium-sized irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Tumor cells are highly columnar with nuclei aligned
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=True →  cell type - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Tumor cells are densely columnar with nuclei aligned
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Adenocarcinoma
# Label=False → enoma
# Label=False → enocarcinoma
# Label=False → enocarcinoma
# Label=False → enia with solid nucleus showing dense nuclear anvil formation or fusion and tumor tissue is observed.
# Label=True →  cell proliferation Isotopic adenocarcinoma - Tumor cells are highly columnar with nuclei aligned basolaterally. Tumor cells are highly columnar with nuclei aligned basolaterally. tumor tissue consisting of alveolar and diffuse tumor cells is observed.
# Label=True → in structure
# Label=True → etioma - Tumor tissue that infiltrates the muscular tissue of the muscularis mucosae by forming medium-sized irregular ducts is observed. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. tumor cells are highly columnar, with nuclei aligned bas
# Label=False → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=True → et-type - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. Solid-type
# Label=False →  adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. tumor cells are highly columnar and show large nucleus and large nuclei.
# Label=False →  differentiated tubular adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True → atinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells exhibit a nuclear type and are heterogeneous.
# Label=True → atinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized.
# Label=True →  differentiated tubular adenocarcinoma - Tumor tissue consisting of a large sheet-like shape and irregular ducts fused is observed in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Tumor cells exhibit highly polarized nuclei
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar and show an alveolar shape.
# Label=False → atinoma - In the superficial epithelium, tumor tissue that invades by forming medium-sized to small, irregular ducts is observed. tumor tissue that infiltrates by forming medium-sized to small ducts is observed. tumor-associated tumor cells exhibit a high level of nucleotides and are highly columnar
# Label=True → eniglioma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Well differentiated tubular adenocarcinoma
# Label=False → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular ducts is observed infiltrating in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized.
# Label=False → et adenocarcinoma - Tumor tissue consisting of medium-sized and irregular glandular ducts fused and infiltrated is observed in the superficial epithelium. Tumor cells are highly columnar, with nuclei aligned basolaterally and polarized. tumor tissue with somatostatin cell type
# Label=True → etioma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Tumor cells are highly columnar and form large irregular nuclear or irregular glandular ducts. Poorly differentiated adenocarcinoma, solid type or
# Label=False → enocarcinoma - Tumor tissue consisting of medium-sized, cord-like or irregular glandular infiltration is observed in the superficial epithelium. Poorly differentiated adenocarcinoma, non-solid type or moderately differentiated tubular adenocarcinoma
# Label=False → et infarctatum - Atypical epithelium is found in the superficial epithelium. Tumor cells are highly columnar with nuclei aligned basolaterally and polarized. Atypical tumor tissue is found in the solid-colored nucleus.
#                                                image  label  \
# 0  <PIL.PngImagePlugin.PngImageFile image mode=RG...  False
# 1  <PIL.PngImagePlugin.PngImageFile image mode=RG...   True
# 2  <PIL.PngImagePlugin.PngImageFile image mode=RG...  False
# 3  <PIL.PngImagePlugin.PngImageFile image mode=RG...   True
# 4  <PIL.PngImagePlugin.PngImageFile image mode=RG...   True
#
#                                              caption
# 0  enoma - Tumor tissue consisting of medium-size...
# 1  enocarcinoma - In the superficial epithelium, ...
# 2  enocarcinoma - Tumor tissue consisting of cord...
# 3  enocarcinoma - On the superficial epithelium, ...
# 4   solid type - Tumor tissue consisting of cord-...

# %%
df.to_pickle("/content/drive/MyDrive/patchcamelyon_captions_df_testdata500.pkl")

# %%
testdf = pd.read_pickle("/content/drive/MyDrive/patchcamelyon_captions_df_testdata500.pkl")

# %%
testdf.head()
# Out:
#                                                image  label  \
# 0  <PIL.PngImagePlugin.PngImageFile image mode=RG...  False
# 1  <PIL.PngImagePlugin.PngImageFile image mode=RG...   True
# 2  <PIL.PngImagePlugin.PngImageFile image mode=RG...  False
# 3  <PIL.PngImagePlugin.PngImageFile image mode=RG...   True
# 4  <PIL.PngImagePlugin.PngImageFile image mode=RG...   True
#
#                                              caption
# 0  enoma - Tumor tissue consisting of medium-size...
# 1  enocarcinoma - In the superficial epithelium, ...
# 2  enocarcinoma - Tumor tissue consisting of cord...
# 3  enocarcinoma - On the superficial epithelium, ...
# 4   solid type - Tumor tissue consisting of cord-...

# %%
from transformers import LlavaForConditionalGeneration, LlavaProcessor, CLIPProcessor, CLIPModel, BlipProcessor, BlipForConditionalGeneration

# %%
hf_token = "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"

# %%
img_embs = []
for img in tqdm(testdf["image"], desc="Embedding images"):
    inputs = clip_processor(images=img, return_tensors="pt").to("cuda")
    with torch.no_grad():
        feat = clip_model.get_image_features(**inputs)  # (1, 768)
    feat = feat / feat.norm(dim=-1, keepdim=True)
    img_embs.append(feat.cpu().numpy())

img_embs = np.vstack(img_embs)  # (N, 768)

txt_embs = text_embedder.encode(
    testdf["caption"].tolist(),
    batch_size=64,
    show_progress_bar=True,
    convert_to_numpy=True,
)
# Out:
# Embedding images:   0%|          | 0/500 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
import pickle

images = testdf["image"].tolist()
# Extract relevant parts from DataFrame
captions = testdf["caption"].tolist()
labels = testdf["label"].tolist()  # Make sure 'label' column exists

# Bundle everything into a dictionary
data_to_save = {
    "images": images,
    "captions": captions,
    "labels": labels,
    "image_embeddings": img_embs,
    "text_embeddings": txt_embs
}

# Save to pickle file
with open("embeddings_and_labels.pkl", "wb") as f:
    pickle.dump(data_to_save, f)

# %%
with open("/content/drive/MyDrive/patchcamelyon_embeddings_testdata500.pkl", "wb") as f:
  pickle.dump(data_to_save, f)

# %% [markdown]
# ### Start from here inference

# %%
import os, json, pickle
import numpy as np
import faiss

# %%
# 1) Paths for your new RAG store
BASE_PATH  = "/content/drive/MyDrive/pcam_rag_index_withlables_new"
INDEX_PATH = os.path.join(BASE_PATH, "caption_image_index.faiss")
META_PATH  = os.path.join(BASE_PATH, "metadata.jsonl")

# %%
index = faiss.read_index(INDEX_PATH)
docs  = [json.loads(line) for line in open(META_PATH, "r")]
print(f"Index: {index.ntotal} vectors; metadata entries: {len(docs)}")
# Out:
# Index: 14311 vectors; metadata entries: 14311

# %%
PICKLE_IN = "/content/drive/MyDrive/patchcamelyon_embeddings_testdata500.pkl"
with open(PICKLE_IN, "rb") as f:
    test_data = pickle.load(f)

# %%
test_images   = test_data["images"]              # list of PIL.Image
test_captions = test_data["captions"]            # list of str
test_labels   = test_data["labels"]              # list of int
test_img_embs = np.array(test_data["image_embeddings"], dtype=np.float32)
test_txt_embs = np.array(test_data["text_embeddings"], dtype=np.float32)

# %%
faiss.normalize_L2(test_img_embs)
faiss.normalize_L2(test_txt_embs)

# %%
alpha = 1.0          # weight for image
beta  = 1.0 - alpha  # weight for text
k     = 10

# %%
img_dim = test_img_embs.shape[1]

# %%
rag_results = []
for i in range(len(test_img_embs)):
    # weighted fusion
    q_img = test_img_embs[i] * alpha
    q_txt = test_txt_embs[i] * beta
    q = np.concatenate([q_img, q_txt], axis=0).reshape(1, -1)
    faiss.normalize_L2(q)

    # search
    D, I = index.search(q, k)
    neighs = []
    for score, idx in zip(D[0], I[0]):
        entry = docs[idx].copy()
        neighs.append({
            "id":      entry.get("id"),
            "caption": entry.get("caption"),
            "label":   entry.get("label"),
            "score":   float(score),
            # If you stored the combined embeddings you could also
            # reconstruct them here with index.reconstruct(idx)
        })
    rag_results.append(neighs)

print(f"Retrieved top-{k} neighbors for each of {len(rag_results)} test samples")
# Out:
# Retrieved top-10 neighbors for each of 500 test samples

# %%
import json
import torch
from PIL import Image
from transformers import (
    LlavaForConditionalGeneration,
    LlavaProcessor,
    BitsAndBytesConfig,
)
from sentence_transformers import SentenceTransformer
import faiss, numpy as np, pickle, os

# %%
DEVICE   = "cuda"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_threshold=6.0,
    llm_int8_has_fp16_weight=False,
)

model = LlavaForConditionalGeneration.from_pretrained(
    "llava-hf/llava-1.5-7b-hf",
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
    token=hf_token,
).eval().to(DEVICE)

processor = LlavaProcessor.from_pretrained(
    "llava-hf/llava-1.5-7b-hf",
    token=hf_token
)
# Out:
# config.json:   0%|          | 0.00/950 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/70.1k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.18G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/701 [00:00<?, ?B/s]

# %%
system_msg = """you are a medical assistant trained to classify histopathologic images as tumor (label 1) or normal (label 0).
Just give 0 or 1 as response. 0 if there is no cancer, 1 if cancer.
Dont give any explanations.
Think step-by-step based on cellular structure and pathology cues.
Then output your final answer in the format:<label>"""
user_step1 = "Step 1: Study the following similar examples and their labels."

# %%
def make_prompt(test_caption, neighbors):
    # 1) Instruction
    instr = (
        "\n"
        "### Instruction:\n"
        "You are a medical assistant trained to classify histopathologic images as tumor (1) or normal (0).\n"
        "Only respond with a single digit (0 or 1), no explanations.\n"
        "Think step-by-step based on cellular structure and pathology cues.\n\n"
    )

    # 2) Few‐shot examples
    ex_str = "### Examples:\n"
    for n in neighbors:
        ex_str += (
            f"Caption: {n['caption']}\n"
            f"Answer: {n['label']}\n\n"
        )

    # 3) Query
    query = (
        "### Query:\n"
        f"Caption: {test_caption}\n"
        "Answer:"
    )

    return instr + ex_str + query

# %%
@torch.no_grad()
def predict_with_few_shot(idx):
    # retrieve neighbors as before…
    neighbors = rag_results[idx]  # list of top-10 dicts

    prompt = make_prompt(test_captions[idx], neighbors)

    inputs = processor(
        images=test_images[idx],
        text=prompt,
        return_tensors="pt",
        padding=True,
        truncation=False,   # ensure the  token is never dropped
    ).to(DEVICE)

    gen_ids = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    pixel_values=inputs.pixel_values,
    max_new_tokens=2,                # allow up to “<digit>” + EOS
    num_beams=3,                     # beam search for a cleaner single‐token answer
    do_sample=False,
    pad_token_id=processor.tokenizer.pad_token_id,
    eos_token_id=processor.tokenizer.eos_token_id,
)
    input_len  = inputs.input_ids.shape[-1]
    new_tokens = gen_ids[0, input_len:].cpu().tolist()
    out_text   = processor.tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    # take the first “word” in case there’s a trailing newline
    pred       = out_text.split()[0] if out_text else None
    return pred

# %%
preds = []
for i in range(len(test_images)):
    p = predict_with_few_shot(i)
    print(p)
    preds.append(int(p) if p.isdigit() else None)
    print(f"[{i}] True={test_labels[i]} → Pred={preds[-1]}")

acc = sum(p==t for p,t in zip(preds, test_labels)) / len(test_labels)
print(f"\n10-shot RAG→LLaVA accuracy: {acc:.1%}")
# Out:
# 1
# [0] True=False → Pred=1
# 1
# [1] True=True → Pred=1
# 1
# [2] True=False → Pred=1
# 1
# [3] True=True → Pred=1
# 1
# [4] True=True → Pred=1
# 1
# [5] True=False → Pred=1
# 1
# [6] True=True → Pred=1
# 1
# [7] True=True → Pred=1
# 1
# [8] True=True → Pred=1
# 0
# [9] True=False → Pred=0
# 1
# [10] True=True → Pred=1
# 0
# [11] True=False → Pred=0
# 1
# [12] True=True → Pred=1
# 1
# [13] True=True → Pred=1
# 1
# [14] True=False → Pred=1
# 1
# [15] True=True → Pred=1
# 1
# [16] True=False → Pred=1
# 1
# [17] True=True → Pred=1
# 0
# [18] True=True → Pred=0
# 1
# [19] True=True → Pred=1
# 1
# [20] True=True → Pred=1
# 1
# [21] True=False → Pred=1
# 0
# [22] True=False → Pred=0
# 0
# [23] True=False → Pred=0
# 0
# [24] True=False → Pred=0
# 0
# [25] True=True → Pred=0
# 1
# [26] True=True → Pred=1
# 1
# [27] True=False → Pred=1
# 1
# [28] True=True → Pred=1
# 1
# [29] True=True → Pred=1
# 1
# [30] True=True → Pred=1
# 1
# [31] True=True → Pred=1
# 1
# [32] True=True → Pred=1
# 1
# [33] True=True → Pred=1
# 1
# [34] True=True → Pred=1
# 1
# [35] True=True → Pred=1
# 0
# [36] True=True → Pred=0
# 1
# [37] True=False → Pred=1
# 0
# [38] True=True → Pred=0
# 1
# [39] True=True → Pred=1
# 1
# [40] True=True → Pred=1
# 1
# [41] True=True → Pred=1
# 0
# [42] True=False → Pred=0
# 1
# [43] True=False → Pred=1
# 1
# [44] True=True → Pred=1
# 1
# [45] True=False → Pred=1
# 1
# [46] True=True → Pred=1
# 1
# [47] True=True → Pred=1
# 1
# [48] True=True → Pred=1
# 1
# [49] True=True → Pred=1
# 1
# [50] True=True → Pred=1
# 1
# [51] True=True → Pred=1
# 0
# [52] True=True → Pred=0
# 0
# [53] True=True → Pred=0
# 1
# [54] True=False → Pred=1
# 0
# [55] True=True → Pred=0
# 0
# [56] True=True → Pred=0
# 1
# [57] True=True → Pred=1
# 0
# [58] True=False → Pred=0
# 0
# [59] True=False → Pred=0
# 1
# [60] True=True → Pred=1
# 0
# [61] True=True → Pred=0
# 0
# [62] True=False → Pred=0
# 1
# [63] True=True → Pred=1
# 1
# [64] True=False → Pred=1
# 1
# [65] True=True → Pred=1
# 1
# [66] True=True → Pred=1
# 1
# [67] True=False → Pred=1
# 0
# [68] True=True → Pred=0
# 1
# [69] True=True → Pred=1
# 1
# [70] True=True → Pred=1
# 1
# [71] True=False → Pred=1
# 1
# [72] True=False → Pred=1
# 0
# [73] True=False → Pred=0
# 0
# [74] True=True → Pred=0
# 1
# [75] True=True → Pred=1
# 0
# [76] True=True → Pred=0
# 1
# [77] True=True → Pred=1
# 1
# [78] True=True → Pred=1
# 1
# [79] True=True → Pred=1
# 1
# [80] True=True → Pred=1
# 0
# [81] True=False → Pred=0
# 1
# [82] True=True → Pred=1
# 1
# [83] True=True → Pred=1
# 1
# [84] True=True → Pred=1
# 1
# [85] True=True → Pred=1
# 1
# [86] True=True → Pred=1
# 1
# [87] True=False → Pred=1
# 1
# [88] True=True → Pred=1
# 0
# [89] True=True → Pred=0
# 1
# [90] True=True → Pred=1
# 1
# [91] True=True → Pred=1
# 1
# [92] True=True → Pred=1
# 0
# [93] True=True → Pred=0
# 0
# [94] True=False → Pred=0
# 0
# [95] True=True → Pred=0
# 1
# [96] True=True → Pred=1
# 0
# [97] True=True → Pred=0
# 1
# [98] True=True → Pred=1
# 0
# [99] True=False → Pred=0
# 0
# [100] True=True → Pred=0
# 0
# [101] True=False → Pred=0
# 1
# [102] True=True → Pred=1
# 0
# [103] True=False → Pred=0
# 1
# [104] True=True → Pred=1
# 0
# [105] True=False → Pred=0
# 1
# [106] True=True → Pred=1
# 0
# [107] True=False → Pred=0
# 1
# [108] True=False → Pred=1
# 1
# [109] True=True → Pred=1
# 1
# [110] True=True → Pred=1
# 0
# [111] True=True → Pred=0
# 1
# [112] True=True → Pred=1
# 1
# [113] True=True → Pred=1
# 1
# [114] True=True → Pred=1
# 1
# [115] True=False → Pred=1
# 1
# [116] True=False → Pred=1
# 0
# [117] True=False → Pred=0
# 0
# [118] True=False → Pred=0
# 1
# [119] True=True → Pred=1
# 1
# [120] True=True → Pred=1
# 0
# [121] True=False → Pred=0
# 1
# [122] True=True → Pred=1
# 1
# [123] True=True → Pred=1
# 1
# [124] True=False → Pred=1
# 1
# [125] True=True → Pred=1
# 0
# [126] True=True → Pred=0
# 0
# [127] True=True → Pred=0
# 1
# [128] True=False → Pred=1
# 1
# [129] True=False → Pred=1
# 1
# [130] True=True → Pred=1
# 1
# [131] True=True → Pred=1
# 1
# [132] True=True → Pred=1
# 1
# [133] True=False → Pred=1
# 1
# [134] True=True → Pred=1
# 1
# [135] True=False → Pred=1
# 1
# [136] True=False → Pred=1
# 1
# [137] True=True → Pred=1
# 0
# [138] True=False → Pred=0
# 1
# [139] True=True → Pred=1
# 1
# [140] True=True → Pred=1
# 1
# [141] True=True → Pred=1
# 1
# [142] True=True → Pred=1
# 1
# [143] True=False → Pred=1
# 1
# [144] True=True → Pred=1
# 0
# [145] True=False → Pred=0
# 1
# [146] True=False → Pred=1
# 0
# [147] True=False → Pred=0
# 0
# [148] True=False → Pred=0
# 0
# [149] True=False → Pred=0
# 1
# [150] True=False → Pred=1
# 0
# [151] True=False → Pred=0
# 0
# [152] True=True → Pred=0
# 1
# [153] True=False → Pred=1
# 1
# [154] True=False → Pred=1
# 0
# [155] True=False → Pred=0
# 0
# [156] True=False → Pred=0
# 0
# [157] True=True → Pred=0
# 0
# [158] True=True → Pred=0
# 0
# [159] True=False → Pred=0
# 0
# [160] True=False → Pred=0
# 0
# [161] True=False → Pred=0
# 1
# [162] True=False → Pred=1
# 0
# [163] True=False → Pred=0
# 0
# [164] True=False → Pred=0
# 0
# [165] True=False → Pred=0
# 1
# [166] True=False → Pred=1
# 1
# [167] True=False → Pred=1
# 1
# [168] True=False → Pred=1
# 0
# [169] True=False → Pred=0
# 1
# [170] True=True → Pred=1
# 0
# [171] True=False → Pred=0
# 0
# [172] True=False → Pred=0
# 0
# [173] True=False → Pred=0
# 1
# [174] True=True → Pred=1
# 0
# [175] True=False → Pred=0
# 1
# [176] True=True → Pred=1
# 1
# [177] True=True → Pred=1
# 1
# [178] True=True → Pred=1
# 1
# [179] True=True → Pred=1
# 0
# [180] True=False → Pred=0
# 1
# [181] True=True → Pred=1
# 1
# [182] True=True → Pred=1
# 1
# [183] True=False → Pred=1
# 0
# [184] True=False → Pred=0
# 1
# [185] True=True → Pred=1
# 0
# [186] True=False → Pred=0
# 0
# [187] True=False → Pred=0
# 0
# [188] True=False → Pred=0
# 0
# [189] True=False → Pred=0
# 1
# [190] True=False → Pred=1
# 1
# [191] True=True → Pred=1
# 0
# [192] True=False → Pred=0
# 0
# [193] True=False → Pred=0
# 0
# [194] True=False → Pred=0
# 0
# [195] True=True → Pred=0
# 0
# [196] True=False → Pred=0
# 0
# [197] True=False → Pred=0
# 0
# [198] True=True → Pred=0
# 0
# [199] True=True → Pred=0
# 1
# [200] True=False → Pred=1
# 0
# [201] True=False → Pred=0
# 1
# [202] True=False → Pred=1
# 1
# [203] True=False → Pred=1
# 0
# [204] True=False → Pred=0
# 1
# [205] True=True → Pred=1
# 1
# [206] True=True → Pred=1
# 1
# [207] True=False → Pred=1
# 1
# [208] True=True → Pred=1
# 1
# [209] True=True → Pred=1
# 1
# [210] True=True → Pred=1
# 0
# [211] True=True → Pred=0
# 0
# [212] True=True → Pred=0
# 1
# [213] True=True → Pred=1
# 1
# [214] True=False → Pred=1
# 0
# [215] True=True → Pred=0
# 0
# [216] True=False → Pred=0
# 1
# [217] True=True → Pred=1
# 1
# [218] True=True → Pred=1
# 1
# [219] True=True → Pred=1
# 1
# [220] True=True → Pred=1
# 1
# [221] True=False → Pred=1
# 1
# [222] True=False → Pred=1
# 1
# [223] True=True → Pred=1
# 0
# [224] True=False → Pred=0
# 1
# [225] True=True → Pred=1
# 0
# [226] True=True → Pred=0
# 1
# [227] True=True → Pred=1
# 0
# [228] True=False → Pred=0
# 0
# [229] True=True → Pred=0
# 0
# [230] True=True → Pred=0
# 0
# [231] True=False → Pred=0
# 0
# [232] True=True → Pred=0
# 0
# [233] True=False → Pred=0
# 0
# [234] True=False → Pred=0
# 0
# [235] True=False → Pred=0
# 0
# [236] True=True → Pred=0
# 1
# [237] True=True → Pred=1
# 1
# [238] True=True → Pred=1
# 1
# [239] True=True → Pred=1
# 1
# [240] True=True → Pred=1
# 1
# [241] True=True → Pred=1
# 0
# [242] True=False → Pred=0
# 0
# [243] True=False → Pred=0
# 1
# [244] True=False → Pred=1
# 0
# [245] True=False → Pred=0
# 1
# [246] True=False → Pred=1
# 1
# [247] True=True → Pred=1
# 1
# [248] True=True → Pred=1
# 0
# [249] True=False → Pred=0
# 1
# [250] True=True → Pred=1
# 0
# [251] True=True → Pred=0
# 1
# [252] True=False → Pred=1
# 1
# [253] True=True → Pred=1
# 0
# [254] True=False → Pred=0
# 0
# [255] True=True → Pred=0
# 0
# [256] True=False → Pred=0
# 0
# [257] True=False → Pred=0
# 0
# [258] True=False → Pred=0
# 0
# [259] True=True → Pred=0
# 1
# [260] True=True → Pred=1
# 1
# [261] True=True → Pred=1
# 0
# [262] True=True → Pred=0
# 0
# [263] True=False → Pred=0
# 0
# [264] True=False → Pred=0
# 1
# [265] True=False → Pred=1
# 1
# [266] True=True → Pred=1
# 0
# [267] True=False → Pred=0
# 0
# [268] True=False → Pred=0
# 0
# [269] True=True → Pred=0
# 0
# [270] True=True → Pred=0
# 0
# [271] True=False → Pred=0
# 1
# [272] True=False → Pred=1
# 0
# [273] True=False → Pred=0
# 0
# [274] True=False → Pred=0
# 0
# [275] True=False → Pred=0
# 1
# [276] True=False → Pred=1
# 0
# [277] True=False → Pred=0
# 0
# [278] True=False → Pred=0
# 0
# [279] True=False → Pred=0
# 1
# [280] True=False → Pred=1
# 1
# [281] True=True → Pred=1
# 1
# [282] True=True → Pred=1
# 0
# [283] True=False → Pred=0
# 0
# [284] True=False → Pred=0
# 0
# [285] True=True → Pred=0
# 1
# [286] True=False → Pred=1
# 1
# [287] True=False → Pred=1
# 1
# [288] True=False → Pred=1
# 0
# [289] True=False → Pred=0
# 1
# [290] True=False → Pred=1
# 1
# [291] True=True → Pred=1
# 1
# [292] True=True → Pred=1
# 0
# [293] True=True → Pred=0
# 1
# [294] True=False → Pred=1
# 0
# [295] True=True → Pred=0
# 1
# [296] True=True → Pred=1
# 0
# [297] True=False → Pred=0
# 1
# [298] True=False → Pred=1
# 1
# [299] True=True → Pred=1
# 0
# [300] True=False → Pred=0
# 0
# [301] True=False → Pred=0
# 0
# [302] True=False → Pred=0
# 1
# [303] True=True → Pred=1
# 1
# [304] True=True → Pred=1
# 0
# [305] True=False → Pred=0
# 1
# [306] True=False → Pred=1
# 1
# [307] True=True → Pred=1
# 0
# [308] True=False → Pred=0
# 1
# [309] True=False → Pred=1
# 1
# [310] True=False → Pred=1
# 1
# [311] True=False → Pred=1
# 1
# [312] True=True → Pred=1
# 1
# [313] True=True → Pred=1
# 1
# [314] True=False → Pred=1
# 1
# [315] True=False → Pred=1
# 1
# [316] True=False → Pred=1
# 1
# [317] True=False → Pred=1
# 0
# [318] True=False → Pred=0
# 1
# [319] True=True → Pred=1
# 1
# [320] True=True → Pred=1
# 0
# [321] True=True → Pred=0
# 1
# [322] True=False → Pred=1
# 1
# [323] True=False → Pred=1
# 1
# [324] True=True → Pred=1
# 0
# [325] True=False → Pred=0
# 0
# [326] True=False → Pred=0
# 0
# [327] True=True → Pred=0
# 1
# [328] True=True → Pred=1
# 1
# [329] True=False → Pred=1
# 0
# [330] True=False → Pred=0
# 1
# [331] True=True → Pred=1
# 1
# [332] True=False → Pred=1
# 1
# [333] True=False → Pred=1
# 1
# [334] True=False → Pred=1
# 0
# [335] True=False → Pred=0
# 1
# [336] True=True → Pred=1
# 0
# [337] True=False → Pred=0
# 1
# [338] True=True → Pred=1
# 0
# [339] True=True → Pred=0
# 1
# [340] True=False → Pred=1
# 0
# [341] True=False → Pred=0
# 1
# [342] True=True → Pred=1
# 1
# [343] True=False → Pred=1
# 1
# [344] True=True → Pred=1
# 0
# [345] True=False → Pred=0
# 0
# [346] True=False → Pred=0
# 1
# [347] True=False → Pred=1
# 0
# [348] True=True → Pred=0
# 1
# [349] True=True → Pred=1
# 1
# [350] True=False → Pred=1
# 1
# [351] True=False → Pred=1
# 1
# [352] True=True → Pred=1
# 1
# [353] True=True → Pred=1
# 1
# [354] True=True → Pred=1
# 0
# [355] True=False → Pred=0
# 1
# [356] True=True → Pred=1
# 1
# [357] True=True → Pred=1
# 0
# [358] True=False → Pred=0
# 0
# [359] True=False → Pred=0
# 0
# [360] True=False → Pred=0
# 0
# [361] True=False → Pred=0
# 0
# [362] True=False → Pred=0
# 1
# [363] True=True → Pred=1
# 1
# [364] True=True → Pred=1
# 1
# [365] True=False → Pred=1
# 0
# [366] True=False → Pred=0
# 0
# [367] True=True → Pred=0
# 0
# [368] True=False → Pred=0
# 1
# [369] True=True → Pred=1
# 1
# [370] True=True → Pred=1
# 1
# [371] True=False → Pred=1
# 0
# [372] True=True → Pred=0
# 1
# [373] True=True → Pred=1
# 1
# [374] True=True → Pred=1
# 1
# [375] True=False → Pred=1
# 1
# [376] True=False → Pred=1
# 0
# [377] True=True → Pred=0
# 1
# [378] True=False → Pred=1
# 1
# [379] True=True → Pred=1
# 0
# [380] True=False → Pred=0
# 1
# [381] True=False → Pred=1
# 1
# [382] True=True → Pred=1
# 1
# [383] True=True → Pred=1
# 1
# [384] True=True → Pred=1
# 1
# [385] True=True → Pred=1
# 1
# [386] True=True → Pred=1
# 1
# [387] True=True → Pred=1
# 1
# [388] True=True → Pred=1
# 1
# [389] True=True → Pred=1
# 1
# [390] True=True → Pred=1
# 0
# [391] True=False → Pred=0
# 0
# [392] True=False → Pred=0
# 1
# [393] True=False → Pred=1
# 1
# [394] True=True → Pred=1
# 0
# [395] True=False → Pred=0
# 1
# [396] True=False → Pred=1
# 0
# [397] True=False → Pred=0
# 1
# [398] True=True → Pred=1
# 1
# [399] True=True → Pred=1
# 1
# [400] True=True → Pred=1
# 1
# [401] True=False → Pred=1
# 1
# [402] True=False → Pred=1
# 1
# [403] True=True → Pred=1
# 1
# [404] True=True → Pred=1
# 0
# [405] True=False → Pred=0
# 0
# [406] True=False → Pred=0
# 1
# [407] True=True → Pred=1
# 0
# [408] True=False → Pred=0
# 1
# [409] True=True → Pred=1
# 1
# [410] True=True → Pred=1
# 1
# [411] True=True → Pred=1
# 0
# [412] True=False → Pred=0
# 1
# [413] True=True → Pred=1
# 1
# [414] True=False → Pred=1
# 1
# [415] True=True → Pred=1
# 1
# [416] True=False → Pred=1
# 0
# [417] True=False → Pred=0
# 0
# [418] True=False → Pred=0
# 0
# [419] True=False → Pred=0
# 1
# [420] True=True → Pred=1
# 0
# [421] True=False → Pred=0
# 0
# [422] True=False → Pred=0
# 1
# [423] True=True → Pred=1
# 1
# [424] True=True → Pred=1
# 0
# [425] True=True → Pred=0
# 0
# [426] True=False → Pred=0
# 0
# [427] True=True → Pred=0
# 0
# [428] True=False → Pred=0
# 1
# [429] True=True → Pred=1
# 1
# [430] True=True → Pred=1
# 1
# [431] True=True → Pred=1
# 1
# [432] True=False → Pred=1
# 0
# [433] True=False → Pred=0
# 1
# [434] True=True → Pred=1
# 1
# [435] True=True → Pred=1
# 1
# [436] True=True → Pred=1
# 1
# [437] True=True → Pred=1
# 1
# [438] True=True → Pred=1
# 0
# [439] True=False → Pred=0
# 1
# [440] True=True → Pred=1
# 1
# [441] True=True → Pred=1
# 1
# [442] True=True → Pred=1
# 0
# [443] True=False → Pred=0
# 0
# [444] True=False → Pred=0
# 1
# [445] True=True → Pred=1
# 0
# [446] True=False → Pred=0
# 1
# [447] True=True → Pred=1
# 0
# [448] True=False → Pred=0
# 1
# [449] True=True → Pred=1
# 1
# [450] True=False → Pred=1
# 1
# [451] True=True → Pred=1
# 1
# [452] True=True → Pred=1
# 1
# [453] True=True → Pred=1
# 1
# [454] True=True → Pred=1
# 0
# [455] True=True → Pred=0
# 1
# [456] True=True → Pred=1
# 1
# [457] True=True → Pred=1
# 1
# [458] True=True → Pred=1
# 1
# [459] True=True → Pred=1
# 0
# [460] True=False → Pred=0
# 1
# [461] True=False → Pred=1
# 1
# [462] True=True → Pred=1
# 1
# [463] True=True → Pred=1
# 0
# [464] True=True → Pred=0
# 0
# [465] True=False → Pred=0
# 1
# [466] True=True → Pred=1
# 1
# [467] True=True → Pred=1
# 1
# [468] True=True → Pred=1
# 1
# [469] True=True → Pred=1
# 1
# [470] True=True → Pred=1
# 1
# [471] True=True → Pred=1
# 0
# [472] True=True → Pred=0
# 1
# [473] True=False → Pred=1
# 1
# [474] True=True → Pred=1
# 1
# [475] True=True → Pred=1
# 1
# [476] True=True → Pred=1
# 0
# [477] True=False → Pred=0
# 0
# [478] True=False → Pred=0
# 0
# [479] True=False → Pred=0
# 1
# [480] True=False → Pred=1
# 1
# [481] True=False → Pred=1
# 1
# [482] True=True → Pred=1
# 1
# [483] True=True → Pred=1
# 1
# [484] True=True → Pred=1
# 0
# [485] True=False → Pred=0
# 0
# [486] True=True → Pred=0
# 0
# [487] True=False → Pred=0
# 1
# [488] True=False → Pred=1
# 1
# [489] True=True → Pred=1
# 1
# [490] True=True → Pred=1
# 1
# [491] True=True → Pred=1
# 0
# [492] True=False → Pred=0
# 0
# [493] True=False → Pred=0
# 0
# [494] True=True → Pred=0
# 0
# [495] True=False → Pred=0
# 1
# [496] True=False → Pred=1
# 1
# [497] True=True → Pred=1
# 0
# [498] True=False → Pred=0
# 1
# [499] True=False → Pred=1
#
# 10-shot RAG→LLaVA accuracy: 69.4%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# If you have any None‐predictions, filter them out
valid_idx = [i for i, p in enumerate(preds) if p is not None]
y_true = [test_labels[i] for i in valid_idx]
y_pred = [preds[i]      for i in valid_idx]

# Compute metrics
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1-score : {f1:.4f}")
# Out:
# Accuracy : 0.6940
# Precision: 0.6863
# Recall   : 0.7865
# F1-score : 0.7330

# %%
preds = []
for i in range(len(test_images)):
    p = predict_with_few_shot(i)
    print(p)
    preds.append(int(p) if p.isdigit() else None)
    print(f"[{i}] True={test_labels[i]} → Pred={preds[-1]}")

acc = sum(p==t for p,t in zip(preds, test_labels)) / len(test_labels)
print(f"\n10-shot RAG→LLaVA accuracy: {acc:.1%}")
# Out:
# 0
# [0] True=False → Pred=0
# 1
# [1] True=True → Pred=1
# 0
# [2] True=False → Pred=0
# 1
# [3] True=True → Pred=1
# 0
# [4] True=True → Pred=0
# 1
# [5] True=False → Pred=1
# 1
# [6] True=True → Pred=1
# 1
# [7] True=True → Pred=1
# 1
# [8] True=True → Pred=1
# 0
# [9] True=False → Pred=0
# 0
# [10] True=True → Pred=0
# 1
# [11] True=False → Pred=1
# 1
# [12] True=True → Pred=1
# 1
# [13] True=True → Pred=1
# 0
# [14] True=False → Pred=0
# 0
# [15] True=True → Pred=0
# 1
# [16] True=False → Pred=1
# 1
# [17] True=True → Pred=1
# 1
# [18] True=True → Pred=1
# 0
# [19] True=True → Pred=0
# 1
# [20] True=True → Pred=1
# 0
# [21] True=False → Pred=0
# 0
# [22] True=False → Pred=0
# 0
# [23] True=False → Pred=0
# 0
# [24] True=False → Pred=0
# 0
# [25] True=True → Pred=0
# 1
# [26] True=True → Pred=1
# 1
# [27] True=False → Pred=1
# 1
# [28] True=True → Pred=1
# 1
# [29] True=True → Pred=1
# 0
# [30] True=True → Pred=0
# 0
# [31] True=True → Pred=0
# 1
# [32] True=True → Pred=1
# 1
# [33] True=True → Pred=1
# 1
# [34] True=True → Pred=1
# 1
# [35] True=True → Pred=1
# 0
# [36] True=True → Pred=0
# 1
# [37] True=False → Pred=1
# 1
# [38] True=True → Pred=1
# 0
# [39] True=True → Pred=0
# 1
# [40] True=True → Pred=1
# 1
# [41] True=True → Pred=1
# 0
# [42] True=False → Pred=0
# 0
# [43] True=False → Pred=0
# 1
# [44] True=True → Pred=1
# 1
# [45] True=False → Pred=1
# 1
# [46] True=True → Pred=1
# 1
# [47] True=True → Pred=1
# 1
# [48] True=True → Pred=1
# 1
# [49] True=True → Pred=1
# 1
# [50] True=True → Pred=1
# 1
# [51] True=True → Pred=1
# 1
# [52] True=True → Pred=1
# 1
# [53] True=True → Pred=1
# 1
# [54] True=False → Pred=1
# 1
# [55] True=True → Pred=1
# 1
# [56] True=True → Pred=1
# 1
# [57] True=True → Pred=1
# 1
# [58] True=False → Pred=1
# 1
# [59] True=False → Pred=1
# 0
# [60] True=True → Pred=0
# 1
# [61] True=True → Pred=1
# 0
# [62] True=False → Pred=0
# 1
# [63] True=True → Pred=1
# 0
# [64] True=False → Pred=0
# 0
# [65] True=True → Pred=0
# 1
# [66] True=True → Pred=1
# 1
# [67] True=False → Pred=1
# 1
# [68] True=True → Pred=1
# 1
# [69] True=True → Pred=1
# 1
# [70] True=True → Pred=1
# 1
# [71] True=False → Pred=1
# 1
# [72] True=False → Pred=1
# 0
# [73] True=False → Pred=0
# 1
# [74] True=True → Pred=1
# 1
# [75] True=True → Pred=1
# 1
# [76] True=True → Pred=1
# 1
# [77] True=True → Pred=1
# 1
# [78] True=True → Pred=1
# 1
# [79] True=True → Pred=1
# 1
# [80] True=True → Pred=1
# 0
# [81] True=False → Pred=0
# 1
# [82] True=True → Pred=1
# 1
# [83] True=True → Pred=1
# 1
# [84] True=True → Pred=1
# 1
# [85] True=True → Pred=1
# 0
# [86] True=True → Pred=0
# 1
# [87] True=False → Pred=1
# 1
# [88] True=True → Pred=1
# 1
# [89] True=True → Pred=1
# 1
# [90] True=True → Pred=1
# 1
# [91] True=True → Pred=1
# 1
# [92] True=True → Pred=1
# 1
# [93] True=True → Pred=1
# 0
# [94] True=False → Pred=0
# 1
# [95] True=True → Pred=1
# 1
# [96] True=True → Pred=1
# 0
# [97] True=True → Pred=0
# 1
# [98] True=True → Pred=1
# 1
# [99] True=False → Pred=1
# 1
# [100] True=True → Pred=1
# 1
# [101] True=False → Pred=1
# 1
# [102] True=True → Pred=1
# 0
# [103] True=False → Pred=0
# 1
# [104] True=True → Pred=1
# 0
# [105] True=False → Pred=0
# 1
# [106] True=True → Pred=1
# 0
# [107] True=False → Pred=0
# 1
# [108] True=False → Pred=1
# 1
# [109] True=True → Pred=1
# 1
# [110] True=True → Pred=1
# 1
# [111] True=True → Pred=1
# 1
# [112] True=True → Pred=1
# 1
# [113] True=True → Pred=1
# 1
# [114] True=True → Pred=1
# 1
# [115] True=False → Pred=1
# 1
# [116] True=False → Pred=1
# 0
# [117] True=False → Pred=0
# 1
# [118] True=False → Pred=1
# 1
# [119] True=True → Pred=1
# 1
# [120] True=True → Pred=1
# 0
# [121] True=False → Pred=0
# 1
# [122] True=True → Pred=1
# 1
# [123] True=True → Pred=1
# 0
# [124] True=False → Pred=0
# 1
# [125] True=True → Pred=1
# 1
# [126] True=True → Pred=1
# 1
# [127] True=True → Pred=1
# 0
# [128] True=False → Pred=0
# 1
# [129] True=False → Pred=1
# 1
# [130] True=True → Pred=1
# 1
# [131] True=True → Pred=1
# 1
# [132] True=True → Pred=1
# 1
# [133] True=False → Pred=1
# 1
# [134] True=True → Pred=1
# 1
# [135] True=False → Pred=1
# 1
# [136] True=False → Pred=1
# 1
# [137] True=True → Pred=1
# 0
# [138] True=False → Pred=0
# 1
# [139] True=True → Pred=1
# 1
# [140] True=True → Pred=1
# 1
# [141] True=True → Pred=1
# 1
# [142] True=True → Pred=1
# 1
# [143] True=False → Pred=1
# 1
# [144] True=True → Pred=1
# 0
# [145] True=False → Pred=0
# 1
# [146] True=False → Pred=1
# 0
# [147] True=False → Pred=0
# 0
# [148] True=False → Pred=0
# 1
# [149] True=False → Pred=1
# 1
# [150] True=False → Pred=1
# 0
# [151] True=False → Pred=0
# 1
# [152] True=True → Pred=1
# 0
# [153] True=False → Pred=0
# 1
# [154] True=False → Pred=1
# 0
# [155] True=False → Pred=0
# 0
# [156] True=False → Pred=0
# 1
# [157] True=True → Pred=1
# 0
# [158] True=True → Pred=0
# 0
# [159] True=False → Pred=0
# 0
# [160] True=False → Pred=0
# 0
# [161] True=False → Pred=0
# 1
# [162] True=False → Pred=1
# 0
# [163] True=False → Pred=0
# 0
# [164] True=False → Pred=0
# 1
# [165] True=False → Pred=1
# 1
# [166] True=False → Pred=1
# 0
# [167] True=False → Pred=0
# 1
# [168] True=False → Pred=1
# 0
# [169] True=False → Pred=0
# 1
# [170] True=True → Pred=1
# 0
# [171] True=False → Pred=0
# 1
# [172] True=False → Pred=1
# 0
# [173] True=False → Pred=0
# 1
# [174] True=True → Pred=1
# 1
# [175] True=False → Pred=1
# 1
# [176] True=True → Pred=1
# 1
# [177] True=True → Pred=1
# 1
# [178] True=True → Pred=1
# 0
# [179] True=True → Pred=0
# 1
# [180] True=False → Pred=1
# 1
# [181] True=True → Pred=1
# 1
# [182] True=True → Pred=1
# 0
# [183] True=False → Pred=0
# 1
# [184] True=False → Pred=1
# 0
# [185] True=True → Pred=0
# 0
# [186] True=False → Pred=0
# 0
# [187] True=False → Pred=0
# 1
# [188] True=False → Pred=1
# 0
# [189] True=False → Pred=0
# 0
# [190] True=False → Pred=0
# 1
# [191] True=True → Pred=1
# 0
# [192] True=False → Pred=0
# 1
# [193] True=False → Pred=1
# 1
# [194] True=False → Pred=1
# 1
# [195] True=True → Pred=1
# 0
# [196] True=False → Pred=0
# 0
# [197] True=False → Pred=0
# 1
# [198] True=True → Pred=1
# 1
# [199] True=True → Pred=1
# 1
# [200] True=False → Pred=1
# 1
# [201] True=False → Pred=1
# 0
# [202] True=False → Pred=0
# 0
# [203] True=False → Pred=0
# 0
# [204] True=False → Pred=0
# 0
# [205] True=True → Pred=0
# 1
# [206] True=True → Pred=1
# 0
# [207] True=False → Pred=0
# 1
# [208] True=True → Pred=1
# 1
# [209] True=True → Pred=1
# 1
# [210] True=True → Pred=1
# 0
# [211] True=True → Pred=0
# 0
# [212] True=True → Pred=0
# 1
# [213] True=True → Pred=1
# 1
# [214] True=False → Pred=1
# 0
# [215] True=True → Pred=0
# 0
# [216] True=False → Pred=0
# 0
# [217] True=True → Pred=0
# 1
# [218] True=True → Pred=1
# 1
# [219] True=True → Pred=1
# 1
# [220] True=True → Pred=1
# 0
# [221] True=False → Pred=0
# 0
# [222] True=False → Pred=0
# 1
# [223] True=True → Pred=1
# 0
# [224] True=False → Pred=0
# 1
# [225] True=True → Pred=1
# 0
# [226] True=True → Pred=0
# 1
# [227] True=True → Pred=1
# 0
# [228] True=False → Pred=0
# 1
# [229] True=True → Pred=1
# 1
# [230] True=True → Pred=1
# 1
# [231] True=False → Pred=1
# 1
# [232] True=True → Pred=1
# 1
# [233] True=False → Pred=1
# 0
# [234] True=False → Pred=0
# 0
# [235] True=False → Pred=0
# 0
# [236] True=True → Pred=0
# 1
# [237] True=True → Pred=1
# 1
# [238] True=True → Pred=1
# 1
# [239] True=True → Pred=1
# 1
# [240] True=True → Pred=1
# 1
# [241] True=True → Pred=1
# 1
# [242] True=False → Pred=1
# 0
# [243] True=False → Pred=0
# 0
# [244] True=False → Pred=0
# 0
# [245] True=False → Pred=0
# 0
# [246] True=False → Pred=0
# 1
# [247] True=True → Pred=1
# 1
# [248] True=True → Pred=1
# 0
# [249] True=False → Pred=0
# 1
# [250] True=True → Pred=1
# 1
# [251] True=True → Pred=1
# 0
# [252] True=False → Pred=0
# 1
# [253] True=True → Pred=1
# 0
# [254] True=False → Pred=0
# 1
# [255] True=True → Pred=1
# 0
# [256] True=False → Pred=0
# 0
# [257] True=False → Pred=0
# 0
# [258] True=False → Pred=0
# 0
# [259] True=True → Pred=0
# 1
# [260] True=True → Pred=1
# 1
# [261] True=True → Pred=1
# 1
# [262] True=True → Pred=1
# 0
# [263] True=False → Pred=0
# 0
# [264] True=False → Pred=0
# 1
# [265] True=False → Pred=1
# 1
# [266] True=True → Pred=1
# 0
# [267] True=False → Pred=0
# 0
# [268] True=False → Pred=0
# 1
# [269] True=True → Pred=1
# 1
# [270] True=True → Pred=1
# 0
# [271] True=False → Pred=0
# 0
# [272] True=False → Pred=0
# 0
# [273] True=False → Pred=0
# 0
# [274] True=False → Pred=0
# 1
# [275] True=False → Pred=1
# 0
# [276] True=False → Pred=0
# 0
# [277] True=False → Pred=0
# 1
# [278] True=False → Pred=1
# 1
# [279] True=False → Pred=1
# 0
# [280] True=False → Pred=0
# 1
# [281] True=True → Pred=1
# 1
# [282] True=True → Pred=1
# 1
# [283] True=False → Pred=1
# 0
# [284] True=False → Pred=0
# 1
# [285] True=True → Pred=1
# 1
# [286] True=False → Pred=1
# 1
# [287] True=False → Pred=1
# 0
# [288] True=False → Pred=0
# 0
# [289] True=False → Pred=0
# 1
# [290] True=False → Pred=1
# 1
# [291] True=True → Pred=1
# 0
# [292] True=True → Pred=0
# 0
# [293] True=True → Pred=0
# 1
# [294] True=False → Pred=1
# 0
# [295] True=True → Pred=0
# 1
# [296] True=True → Pred=1
# 0
# [297] True=False → Pred=0
# 0
# [298] True=False → Pred=0
# 0
# [299] True=True → Pred=0
# 1
# [300] True=False → Pred=1
# 0
# [301] True=False → Pred=0
# 1
# [302] True=False → Pred=1
# 1
# [303] True=True → Pred=1
# 1
# [304] True=True → Pred=1
# 0
# [305] True=False → Pred=0
# 1
# [306] True=False → Pred=1
# 1
# [307] True=True → Pred=1
# 0
# [308] True=False → Pred=0
# 0
# [309] True=False → Pred=0
# 1
# [310] True=False → Pred=1
# 1
# [311] True=False → Pred=1
# 1
# [312] True=True → Pred=1
# 1
# [313] True=True → Pred=1
# 1
# [314] True=False → Pred=1
# 0
# [315] True=False → Pred=0
# 1
# [316] True=False → Pred=1
# 1
# [317] True=False → Pred=1
# 0
# [318] True=False → Pred=0
# 1
# [319] True=True → Pred=1
# 1
# [320] True=True → Pred=1
# 0
# [321] True=True → Pred=0
# 0
# [322] True=False → Pred=0
# 1
# [323] True=False → Pred=1
# 1
# [324] True=True → Pred=1
# 1
# [325] True=False → Pred=1
# 1
# [326] True=False → Pred=1
# 1
# [327] True=True → Pred=1
# 1
# [328] True=True → Pred=1
# 1
# [329] True=False → Pred=1
# 0
# [330] True=False → Pred=0
# 1
# [331] True=True → Pred=1
# 1
# [332] True=False → Pred=1
# 0
# [333] True=False → Pred=0
# 1
# [334] True=False → Pred=1
# 0
# [335] True=False → Pred=0
# 1
# [336] True=True → Pred=1
# 1
# [337] True=False → Pred=1
# 1
# [338] True=True → Pred=1
# 0
# [339] True=True → Pred=0
# 0
# [340] True=False → Pred=0
# 0
# [341] True=False → Pred=0
# 1
# [342] True=True → Pred=1
# 1
# [343] True=False → Pred=1
# 1
# [344] True=True → Pred=1
# 0
# [345] True=False → Pred=0
# 0
# [346] True=False → Pred=0
# 1
# [347] True=False → Pred=1
# 0
# [348] True=True → Pred=0
# 1
# [349] True=True → Pred=1
# 1
# [350] True=False → Pred=1
# 1
# [351] True=False → Pred=1
# 1
# [352] True=True → Pred=1
# 1
# [353] True=True → Pred=1
# 1
# [354] True=True → Pred=1
# 1
# [355] True=False → Pred=1
# 1
# [356] True=True → Pred=1
# 1
# [357] True=True → Pred=1
# 0
# [358] True=False → Pred=0
# 1
# [359] True=False → Pred=1
# 1
# [360] True=False → Pred=1
# 1
# [361] True=False → Pred=1
# 0
# [362] True=False → Pred=0
# 1
# [363] True=True → Pred=1
# 1
# [364] True=True → Pred=1
# 0
# [365] True=False → Pred=0
# 0
# [366] True=False → Pred=0
# 0
# [367] True=True → Pred=0
# 0
# [368] True=False → Pred=0
# 1
# [369] True=True → Pred=1
# 1
# [370] True=True → Pred=1
# 0
# [371] True=False → Pred=0
# 0
# [372] True=True → Pred=0
# 1
# [373] True=True → Pred=1
# 1
# [374] True=True → Pred=1
# 1
# [375] True=False → Pred=1
# 0
# [376] True=False → Pred=0
# 1
# [377] True=True → Pred=1
# 0
# [378] True=False → Pred=0
# 1
# [379] True=True → Pred=1
# 0
# [380] True=False → Pred=0
# 0
# [381] True=False → Pred=0
# 1
# [382] True=True → Pred=1
# 0
# [383] True=True → Pred=0
# 1
# [384] True=True → Pred=1
# 1
# [385] True=True → Pred=1
# 1
# [386] True=True → Pred=1
# 1
# [387] True=True → Pred=1
# 1
# [388] True=True → Pred=1
# 1
# [389] True=True → Pred=1
# 1
# [390] True=True → Pred=1
# 0
# [391] True=False → Pred=0
# 0
# [392] True=False → Pred=0
# 0
# [393] True=False → Pred=0
# 0
# [394] True=True → Pred=0
# 0
# [395] True=False → Pred=0
# 1
# [396] True=False → Pred=1
# 0
# [397] True=False → Pred=0
# 1
# [398] True=True → Pred=1
# 1
# [399] True=True → Pred=1
# 1
# [400] True=True → Pred=1
# 0
# [401] True=False → Pred=0
# 1
# [402] True=False → Pred=1
# 0
# [403] True=True → Pred=0
# 1
# [404] True=True → Pred=1
# 1
# [405] True=False → Pred=1
# 1
# [406] True=False → Pred=1
# 1
# [407] True=True → Pred=1
# 0
# [408] True=False → Pred=0
# 1
# [409] True=True → Pred=1
# 0
# [410] True=True → Pred=0
# 1
# [411] True=True → Pred=1
# 1
# [412] True=False → Pred=1
# 0
# [413] True=True → Pred=0
# 1
# [414] True=False → Pred=1
# 1
# [415] True=True → Pred=1
# 0
# [416] True=False → Pred=0
# 1
# [417] True=False → Pred=1
# 0
# [418] True=False → Pred=0
# 0
# [419] True=False → Pred=0
# 1
# [420] True=True → Pred=1
# 1
# [421] True=False → Pred=1
# 1
# [422] True=False → Pred=1
# 1
# [423] True=True → Pred=1
# 1
# [424] True=True → Pred=1
# 1
# [425] True=True → Pred=1
# 1
# [426] True=False → Pred=1
# 0
# [427] True=True → Pred=0
# 0
# [428] True=False → Pred=0
# 0
# [429] True=True → Pred=0
# 1
# [430] True=True → Pred=1
# 1
# [431] True=True → Pred=1
# 0
# [432] True=False → Pred=0
# 0
# [433] True=False → Pred=0
# 1
# [434] True=True → Pred=1
# 1
# [435] True=True → Pred=1
# 1
# [436] True=True → Pred=1
# 1
# [437] True=True → Pred=1
# 1
# [438] True=True → Pred=1
# 1
# [439] True=False → Pred=1
# 1
# [440] True=True → Pred=1
# 0
# [441] True=True → Pred=0
# 1
# [442] True=True → Pred=1
# 0
# [443] True=False → Pred=0
# 0
# [444] True=False → Pred=0
# 1
# [445] True=True → Pred=1
# 1
# [446] True=False → Pred=1
# 1
# [447] True=True → Pred=1
# 0
# [448] True=False → Pred=0
# 1
# [449] True=True → Pred=1
# 0
# [450] True=False → Pred=0
# 0
# [451] True=True → Pred=0
# 1
# [452] True=True → Pred=1
# 1
# [453] True=True → Pred=1
# 1
# [454] True=True → Pred=1
# 1
# [455] True=True → Pred=1
# 1
# [456] True=True → Pred=1
# 1
# [457] True=True → Pred=1
# 1
# [458] True=True → Pred=1
# 1
# [459] True=True → Pred=1
# 1
# [460] True=False → Pred=1
# 0
# [461] True=False → Pred=0
# 1
# [462] True=True → Pred=1
# 1
# [463] True=True → Pred=1
# 1
# [464] True=True → Pred=1
# 0
# [465] True=False → Pred=0
# 1
# [466] True=True → Pred=1
# 1
# [467] True=True → Pred=1
# 1
# [468] True=True → Pred=1
# 1
# [469] True=True → Pred=1
# 0
# [470] True=True → Pred=0
# 1
# [471] True=True → Pred=1
# 1
# [472] True=True → Pred=1
# 1
# [473] True=False → Pred=1
# 1
# [474] True=True → Pred=1
# 0
# [475] True=True → Pred=0
# 1
# [476] True=True → Pred=1
# 0
# [477] True=False → Pred=0
# 1
# [478] True=False → Pred=1
# 0
# [479] True=False → Pred=0
# 0
# [480] True=False → Pred=0
# 0
# [481] True=False → Pred=0
# 1
# [482] True=True → Pred=1
# 1
# [483] True=True → Pred=1
# 1
# [484] True=True → Pred=1
# 0
# [485] True=False → Pred=0
# 0
# [486] True=True → Pred=0
# 1
# [487] True=False → Pred=1
# 0
# [488] True=False → Pred=0
# 1
# [489] True=True → Pred=1
# 1
# [490] True=True → Pred=1
# 1
# [491] True=True → Pred=1
# 1
# [492] True=False → Pred=1
# 1
# [493] True=False → Pred=1
# 1
# [494] True=True → Pred=1
# 0
# [495] True=False → Pred=0
# 1
# [496] True=False → Pred=1
# 1
# [497] True=True → Pred=1
# 1
# [498] True=False → Pred=1
# 1
# [499] True=False → Pred=1
#
# 10-shot RAG→LLaVA accuracy: 71.2%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# If you have any None‐predictions, filter them out
valid_idx = [i for i, p in enumerate(preds) if p is not None]
y_true = [test_labels[i] for i in valid_idx]
y_pred = [preds[i]      for i in valid_idx]

# Compute metrics
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1-score : {f1:.4f}")
# Out:
# Accuracy : 0.7120
# Precision: 0.6916
# Recall   : 0.8315
# F1-score : 0.7551

# %%
alpha = 5.0          # weight for image
beta  = 1.0 - alpha  # weight for text
k     = 10

# %%
rag_results = []
for i in range(len(test_img_embs)):
    # weighted fusion
    q_img = test_img_embs[i] * alpha
    q_txt = test_txt_embs[i] * beta
    q = np.concatenate([q_img, q_txt], axis=0).reshape(1, -1)
    faiss.normalize_L2(q)

    # search
    D, I = index.search(q, k)
    neighs = []
    for score, idx in zip(D[0], I[0]):
        entry = docs[idx].copy()
        neighs.append({
            "id":      entry.get("id"),
            "caption": entry.get("caption"),
            "label":   entry.get("label"),
            "score":   float(score),
            # If you stored the combined embeddings you could also
            # reconstruct them here with index.reconstruct(idx)
        })
    rag_results.append(neighs)

print(f"Retrieved top-{k} neighbors for each of {len(rag_results)} test samples")
# Out:
# Retrieved top-10 neighbors for each of 500 test samples

# %%
preds = []
for i in range(len(test_images)):
    p = predict_with_few_shot(i)
    print(p)
    preds.append(int(p) if p.isdigit() else None)
    print(f"[{i}] True={test_labels[i]} → Pred={preds[-1]}")

acc = sum(p==t for p,t in zip(preds, test_labels)) / len(test_labels)
print(f"\n10-shot RAG→LLaVA accuracy: {acc:.1%}")
# Out:
# 1
# [0] True=False → Pred=1
# 1
# [1] True=True → Pred=1
# 1
# [2] True=False → Pred=1
# 1
# [3] True=True → Pred=1
# 1
# [4] True=True → Pred=1
# 1
# [5] True=False → Pred=1
# 1
# [6] True=True → Pred=1
# 1
# [7] True=True → Pred=1
# 1
# [8] True=True → Pred=1
# 1
# [9] True=False → Pred=1
# 1
# [10] True=True → Pred=1
# 1
# [11] True=False → Pred=1
# 1
# [12] True=True → Pred=1
# 1
# [13] True=True → Pred=1
# 1
# [14] True=False → Pred=1
# 1
# [15] True=True → Pred=1
# 1
# [16] True=False → Pred=1
# 1
# [17] True=True → Pred=1
# 1
# [18] True=True → Pred=1
# 1
# [19] True=True → Pred=1
# 1
# [20] True=True → Pred=1
# 0
# [21] True=False → Pred=0
# 1
# [22] True=False → Pred=1
# 1
# [23] True=False → Pred=1
# 1
# [24] True=False → Pred=1
# 1
# [25] True=True → Pred=1
# 1
# [26] True=True → Pred=1
# 1
# [27] True=False → Pred=1
# 1
# [28] True=True → Pred=1
# 1
# [29] True=True → Pred=1
# 1
# [30] True=True → Pred=1
# 1
# [31] True=True → Pred=1
# 1
# [32] True=True → Pred=1
# 1
# [33] True=True → Pred=1
# 1
# [34] True=True → Pred=1
# 1
# [35] True=True → Pred=1
# 1
# [36] True=True → Pred=1
# 1
# [37] True=False → Pred=1
# 1
# [38] True=True → Pred=1
# 1
# [39] True=True → Pred=1
# 1
# [40] True=True → Pred=1
# 1
# [41] True=True → Pred=1
# 1
# [42] True=False → Pred=1
# 1
# [43] True=False → Pred=1
# 1
# [44] True=True → Pred=1
# 1
# [45] True=False → Pred=1
# 1
# [46] True=True → Pred=1
# 1
# [47] True=True → Pred=1
# 1
# [48] True=True → Pred=1
# 1
# [49] True=True → Pred=1
# 1
# [50] True=True → Pred=1
# 1
# [51] True=True → Pred=1
# 1
# [52] True=True → Pred=1
# 1
# [53] True=True → Pred=1
# 1
# [54] True=False → Pred=1
# 1
# [55] True=True → Pred=1
# 1
# [56] True=True → Pred=1
# 1
# [57] True=True → Pred=1
# 1
# [58] True=False → Pred=1
# 1
# [59] True=False → Pred=1
# 1
# [60] True=True → Pred=1
# 1
# [61] True=True → Pred=1
# 1
# [62] True=False → Pred=1
# 1
# [63] True=True → Pred=1
# 1
# [64] True=False → Pred=1
# 1
# [65] True=True → Pred=1
# 1
# [66] True=True → Pred=1
# 1
# [67] True=False → Pred=1
# 1
# [68] True=True → Pred=1
# 1
# [69] True=True → Pred=1
# 1
# [70] True=True → Pred=1
# 1
# [71] True=False → Pred=1
# 1
# [72] True=False → Pred=1
# 1
# [73] True=False → Pred=1
# 1
# [74] True=True → Pred=1
# 1
# [75] True=True → Pred=1
# 1
# [76] True=True → Pred=1
# 1
# [77] True=True → Pred=1
# 1
# [78] True=True → Pred=1
# 1
# [79] True=True → Pred=1
# 1
# [80] True=True → Pred=1
# 0
# [81] True=False → Pred=0
# 1
# [82] True=True → Pred=1
# 1
# [83] True=True → Pred=1
# 1
# [84] True=True → Pred=1
# 1
# [85] True=True → Pred=1
# 1
# [86] True=True → Pred=1
# 1
# [87] True=False → Pred=1
# 1
# [88] True=True → Pred=1
# 1
# [89] True=True → Pred=1
# 1
# [90] True=True → Pred=1
# 1
# [91] True=True → Pred=1
# 1
# [92] True=True → Pred=1
# 1
# [93] True=True → Pred=1
# 0
# [94] True=False → Pred=0
# 1
# [95] True=True → Pred=1
# 1
# [96] True=True → Pred=1
# 1
# [97] True=True → Pred=1
# 1
# [98] True=True → Pred=1
# 1
# [99] True=False → Pred=1
# 1
# [100] True=True → Pred=1
# 1
# [101] True=False → Pred=1
# 1
# [102] True=True → Pred=1
# 1
# [103] True=False → Pred=1
# 1
# [104] True=True → Pred=1
# 1
# [105] True=False → Pred=1
# 1
# [106] True=True → Pred=1
# 1
# [107] True=False → Pred=1
# 1
# [108] True=False → Pred=1
# 1
# [109] True=True → Pred=1
# 1
# [110] True=True → Pred=1
# 1
# [111] True=True → Pred=1
# 1
# [112] True=True → Pred=1
# 1
# [113] True=True → Pred=1
# 1
# [114] True=True → Pred=1
# 1
# [115] True=False → Pred=1
# 1
# [116] True=False → Pred=1
# 1
# [117] True=False → Pred=1
# 1
# [118] True=False → Pred=1
# 1
# [119] True=True → Pred=1
# 1
# [120] True=True → Pred=1
# 0
# [121] True=False → Pred=0
# 1
# [122] True=True → Pred=1
# 1
# [123] True=True → Pred=1
# 1
# [124] True=False → Pred=1
# 1
# [125] True=True → Pred=1
# 1
# [126] True=True → Pred=1
# 1
# [127] True=True → Pred=1
# 1
# [128] True=False → Pred=1
# 1
# [129] True=False → Pred=1
# 1
# [130] True=True → Pred=1
# 1
# [131] True=True → Pred=1
# 1
# [132] True=True → Pred=1
# 1
# [133] True=False → Pred=1
# 1
# [134] True=True → Pred=1
# 1
# [135] True=False → Pred=1
# 1
# [136] True=False → Pred=1
# 1
# [137] True=True → Pred=1
# 1
# [138] True=False → Pred=1
# 1
# [139] True=True → Pred=1
# 1
# [140] True=True → Pred=1
# 1
# [141] True=True → Pred=1
# 1
# [142] True=True → Pred=1
# 1
# [143] True=False → Pred=1
# 1
# [144] True=True → Pred=1
# 1
# [145] True=False → Pred=1
# 1
# [146] True=False → Pred=1
# 1
# [147] True=False → Pred=1
# 1
# [148] True=False → Pred=1
# 1
# [149] True=False → Pred=1
# 1
# [150] True=False → Pred=1
# 1
# [151] True=False → Pred=1
# 1
# [152] True=True → Pred=1
# 1
# [153] True=False → Pred=1
# 1
# [154] True=False → Pred=1
# 1
# [155] True=False → Pred=1
# 1
# [156] True=False → Pred=1
# 1
# [157] True=True → Pred=1
# 1
# [158] True=True → Pred=1
# 1
# [159] True=False → Pred=1
# 0
# [160] True=False → Pred=0
# 1
# [161] True=False → Pred=1
# 1
# [162] True=False → Pred=1
# 1
# [163] True=False → Pred=1
# 1
# [164] True=False → Pred=1
# 1
# [165] True=False → Pred=1
# 1
# [166] True=False → Pred=1
# 1
# [167] True=False → Pred=1
# 1
# [168] True=False → Pred=1
# 1
# [169] True=False → Pred=1
# 1
# [170] True=True → Pred=1
# 1
# [171] True=False → Pred=1
# 1
# [172] True=False → Pred=1
# 1
# [173] True=False → Pred=1
# 1
# [174] True=True → Pred=1
# 1
# [175] True=False → Pred=1
# 1
# [176] True=True → Pred=1
# 1
# [177] True=True → Pred=1
# 1
# [178] True=True → Pred=1
# 1
# [179] True=True → Pred=1
# 1
# [180] True=False → Pred=1
# 1
# [181] True=True → Pred=1
# 1
# [182] True=True → Pred=1
# 1
# [183] True=False → Pred=1
# 1
# [184] True=False → Pred=1
# 1
# [185] True=True → Pred=1
# 1
# [186] True=False → Pred=1
# 1
# [187] True=False → Pred=1
# 1
# [188] True=False → Pred=1
# 1
# [189] True=False → Pred=1
# 1
# [190] True=False → Pred=1
# 1
# [191] True=True → Pred=1
# 1
# [192] True=False → Pred=1
# 1
# [193] True=False → Pred=1
# 1
# [194] True=False → Pred=1
# 1
# [195] True=True → Pred=1
# 1
# [196] True=False → Pred=1
# 1
# [197] True=False → Pred=1
# 1
# [198] True=True → Pred=1
# 1
# [199] True=True → Pred=1
# 1
# [200] True=False → Pred=1
# 0
# [201] True=False → Pred=0
# 1
# [202] True=False → Pred=1
# 1
# [203] True=False → Pred=1
# 1
# [204] True=False → Pred=1
# 1
# [205] True=True → Pred=1
# 1
# [206] True=True → Pred=1
# 1
# [207] True=False → Pred=1
# 1
# [208] True=True → Pred=1
# 1
# [209] True=True → Pred=1
# 1
# [210] True=True → Pred=1
# 1
# [211] True=True → Pred=1
# 1
# [212] True=True → Pred=1
# 1
# [213] True=True → Pred=1
# 1
# [214] True=False → Pred=1
# 1
# [215] True=True → Pred=1
# 1
# [216] True=False → Pred=1
# 1
# [217] True=True → Pred=1
# 1
# [218] True=True → Pred=1
# 1
# [219] True=True → Pred=1
# 1
# [220] True=True → Pred=1
# 1
# [221] True=False → Pred=1
# 1
# [222] True=False → Pred=1
# 1
# [223] True=True → Pred=1
# 1
# [224] True=False → Pred=1
# 1
# [225] True=True → Pred=1
# 1
# [226] True=True → Pred=1
# 1
# [227] True=True → Pred=1
# 1
# [228] True=False → Pred=1
# 1
# [229] True=True → Pred=1
# 1
# [230] True=True → Pred=1
# 1
# [231] True=False → Pred=1
# 1
# [232] True=True → Pred=1
# 1
# [233] True=False → Pred=1
# 1
# [234] True=False → Pred=1
# 1
# [235] True=False → Pred=1
# 1
# [236] True=True → Pred=1
# 1
# [237] True=True → Pred=1
# 1
# [238] True=True → Pred=1
# 1
# [239] True=True → Pred=1
# 1
# [240] True=True → Pred=1
# 1
# [241] True=True → Pred=1
# 1
# [242] True=False → Pred=1
# 1
# [243] True=False → Pred=1
# 1
# [244] True=False → Pred=1
# 1
# [245] True=False → Pred=1
# 1
# [246] True=False → Pred=1
# 1
# [247] True=True → Pred=1
# 1
# [248] True=True → Pred=1
# 1
# [249] True=False → Pred=1
# 1
# [250] True=True → Pred=1
# 1
# [251] True=True → Pred=1
# 1
# [252] True=False → Pred=1
# 1
# [253] True=True → Pred=1
# 0
# [254] True=False → Pred=0
# 1
# [255] True=True → Pred=1
# 1
# [256] True=False → Pred=1
# 1
# [257] True=False → Pred=1
# 1
# [258] True=False → Pred=1
# 1
# [259] True=True → Pred=1
# 1
# [260] True=True → Pred=1
# 1
# [261] True=True → Pred=1
# 1
# [262] True=True → Pred=1
# 1
# [263] True=False → Pred=1
# 1
# [264] True=False → Pred=1
# 1
# [265] True=False → Pred=1
# 1
# [266] True=True → Pred=1
# 1
# [267] True=False → Pred=1
# 1
# [268] True=False → Pred=1
# 1
# [269] True=True → Pred=1
# 1
# [270] True=True → Pred=1
# 1
# [271] True=False → Pred=1
# 1
# [272] True=False → Pred=1
# 1
# [273] True=False → Pred=1
# 1
# [274] True=False → Pred=1
# 1
# [275] True=False → Pred=1
# 1
# [276] True=False → Pred=1
# 1
# [277] True=False → Pred=1
# 1
# [278] True=False → Pred=1
# 1
# [279] True=False → Pred=1
# 1
# [280] True=False → Pred=1
# 1
# [281] True=True → Pred=1
# 1
# [282] True=True → Pred=1
# 1
# [283] True=False → Pred=1
# 1
# [284] True=False → Pred=1
# 1
# [285] True=True → Pred=1
# 1
# [286] True=False → Pred=1
# 1
# [287] True=False → Pred=1
# 1
# [288] True=False → Pred=1
# 1
# [289] True=False → Pred=1
# 1
# [290] True=False → Pred=1
# 1
# [291] True=True → Pred=1
# 1
# [292] True=True → Pred=1
# 1
# [293] True=True → Pred=1
# 1
# [294] True=False → Pred=1
# 1
# [295] True=True → Pred=1
# 1
# [296] True=True → Pred=1
# 1
# [297] True=False → Pred=1
# 1
# [298] True=False → Pred=1
# 1
# [299] True=True → Pred=1
# 1
# [300] True=False → Pred=1
# 1
# [301] True=False → Pred=1
# 1
# [302] True=False → Pred=1
# 1
# [303] True=True → Pred=1
# 1
# [304] True=True → Pred=1
# 1
# [305] True=False → Pred=1
# 1
# [306] True=False → Pred=1
# 1
# [307] True=True → Pred=1
# 1
# [308] True=False → Pred=1
# 1
# [309] True=False → Pred=1
# 1
# [310] True=False → Pred=1
# 1
# [311] True=False → Pred=1
# 1
# [312] True=True → Pred=1
# 1
# [313] True=True → Pred=1
# 1
# [314] True=False → Pred=1
# 1
# [315] True=False → Pred=1
# 1
# [316] True=False → Pred=1
# 1
# [317] True=False → Pred=1
# 1
# [318] True=False → Pred=1
# 1
# [319] True=True → Pred=1
# 1
# [320] True=True → Pred=1
# 1
# [321] True=True → Pred=1
# 1
# [322] True=False → Pred=1
# 1
# [323] True=False → Pred=1
# 1
# [324] True=True → Pred=1
# 1
# [325] True=False → Pred=1
# 1
# [326] True=False → Pred=1
# 1
# [327] True=True → Pred=1
# 1
# [328] True=True → Pred=1
# 1
# [329] True=False → Pred=1
# 1
# [330] True=False → Pred=1
# 1
# [331] True=True → Pred=1
# 1
# [332] True=False → Pred=1
# 1
# [333] True=False → Pred=1
# 1
# [334] True=False → Pred=1
# 1
# [335] True=False → Pred=1
# 1
# [336] True=True → Pred=1
# 1
# [337] True=False → Pred=1
# 1
# [338] True=True → Pred=1
# 1
# [339] True=True → Pred=1
# 1
# [340] True=False → Pred=1
# 1
# [341] True=False → Pred=1
# 1
# [342] True=True → Pred=1
# 1
# [343] True=False → Pred=1
# 1
# [344] True=True → Pred=1
# 1
# [345] True=False → Pred=1
# 1
# [346] True=False → Pred=1
# 1
# [347] True=False → Pred=1
# 1
# [348] True=True → Pred=1
# 1
# [349] True=True → Pred=1
# 1
# [350] True=False → Pred=1
# 1
# [351] True=False → Pred=1
# 1
# [352] True=True → Pred=1
# 1
# [353] True=True → Pred=1
# 1
# [354] True=True → Pred=1
# 1
# [355] True=False → Pred=1
# 1
# [356] True=True → Pred=1
# 1
# [357] True=True → Pred=1
# 0
# [358] True=False → Pred=0
# 1
# [359] True=False → Pred=1
# 1
# [360] True=False → Pred=1
# 1
# [361] True=False → Pred=1
# 1
# [362] True=False → Pred=1
# 1
# [363] True=True → Pred=1
# 1
# [364] True=True → Pred=1
# 0
# [365] True=False → Pred=0
# 1
# [366] True=False → Pred=1
# 1
# [367] True=True → Pred=1
# 1
# [368] True=False → Pred=1
# 1
# [369] True=True → Pred=1
# 1
# [370] True=True → Pred=1
# 1
# [371] True=False → Pred=1
# 1
# [372] True=True → Pred=1
# 1
# [373] True=True → Pred=1
# 1
# [374] True=True → Pred=1
# 1
# [375] True=False → Pred=1
# 1
# [376] True=False → Pred=1
# 1
# [377] True=True → Pred=1
# 1
# [378] True=False → Pred=1
# 1
# [379] True=True → Pred=1
# 1
# [380] True=False → Pred=1
# 1
# [381] True=False → Pred=1
# 1
# [382] True=True → Pred=1
# 1
# [383] True=True → Pred=1
# 1
# [384] True=True → Pred=1
# 1
# [385] True=True → Pred=1
# 1
# [386] True=True → Pred=1
# 1
# [387] True=True → Pred=1
# 1
# [388] True=True → Pred=1
# 1
# [389] True=True → Pred=1
# 1
# [390] True=True → Pred=1
# 1
# [391] True=False → Pred=1
# 1
# [392] True=False → Pred=1
# 1
# [393] True=False → Pred=1
# 1
# [394] True=True → Pred=1
# 1
# [395] True=False → Pred=1
# 1
# [396] True=False → Pred=1
# 1
# [397] True=False → Pred=1
# 1
# [398] True=True → Pred=1
# 1
# [399] True=True → Pred=1
# 1
# [400] True=True → Pred=1
# 1
# [401] True=False → Pred=1
# 1
# [402] True=False → Pred=1
# 1
# [403] True=True → Pred=1
# 1
# [404] True=True → Pred=1
# 1
# [405] True=False → Pred=1
# 1
# [406] True=False → Pred=1
# 1
# [407] True=True → Pred=1
# 1
# [408] True=False → Pred=1
# 1
# [409] True=True → Pred=1
# 1
# [410] True=True → Pred=1
# 1
# [411] True=True → Pred=1
# 1
# [412] True=False → Pred=1
# 1
# [413] True=True → Pred=1
# 1
# [414] True=False → Pred=1
# 1
# [415] True=True → Pred=1
# 1
# [416] True=False → Pred=1
# 1
# [417] True=False → Pred=1
# 1
# [418] True=False → Pred=1
# 1
# [419] True=False → Pred=1
# 1
# [420] True=True → Pred=1
# 1
# [421] True=False → Pred=1
# 1
# [422] True=False → Pred=1
# 1
# [423] True=True → Pred=1
# 1
# [424] True=True → Pred=1
# 1
# [425] True=True → Pred=1
# 1
# [426] True=False → Pred=1
# 1
# [427] True=True → Pred=1
# 1
# [428] True=False → Pred=1
# 1
# [429] True=True → Pred=1
# 1
# [430] True=True → Pred=1
# 1
# [431] True=True → Pred=1
# 1
# [432] True=False → Pred=1
# 1
# [433] True=False → Pred=1
# 1
# [434] True=True → Pred=1
# 1
# [435] True=True → Pred=1
# 1
# [436] True=True → Pred=1
# 1
# [437] True=True → Pred=1
# 1
# [438] True=True → Pred=1
# 1
# [439] True=False → Pred=1
# 1
# [440] True=True → Pred=1
# 1
# [441] True=True → Pred=1
# 1
# [442] True=True → Pred=1
# 1
# [443] True=False → Pred=1
# 1
# [444] True=False → Pred=1
# 1
# [445] True=True → Pred=1
# 1
# [446] True=False → Pred=1
# 1
# [447] True=True → Pred=1
# 1
# [448] True=False → Pred=1
# 1
# [449] True=True → Pred=1
# 1
# [450] True=False → Pred=1
# 1
# [451] True=True → Pred=1
# 1
# [452] True=True → Pred=1
# 1
# [453] True=True → Pred=1
# 1
# [454] True=True → Pred=1
# 1
# [455] True=True → Pred=1
# 1
# [456] True=True → Pred=1
# 1
# [457] True=True → Pred=1
# 1
# [458] True=True → Pred=1
# 1
# [459] True=True → Pred=1
# 1
# [460] True=False → Pred=1
# 1
# [461] True=False → Pred=1
# 1
# [462] True=True → Pred=1
# 1
# [463] True=True → Pred=1
# 1
# [464] True=True → Pred=1
# 1
# [465] True=False → Pred=1
# 1
# [466] True=True → Pred=1
# 1
# [467] True=True → Pred=1
# 1
# [468] True=True → Pred=1
# 1
# [469] True=True → Pred=1
# 1
# [470] True=True → Pred=1
# 1
# [471] True=True → Pred=1
# 1
# [472] True=True → Pred=1
# 1
# [473] True=False → Pred=1
# 1
# [474] True=True → Pred=1
# 1
# [475] True=True → Pred=1
# 1
# [476] True=True → Pred=1
# 1
# [477] True=False → Pred=1
# 0
# [478] True=False → Pred=0
# 1
# [479] True=False → Pred=1
# 1
# [480] True=False → Pred=1
# 1
# [481] True=False → Pred=1
# 1
# [482] True=True → Pred=1
# 0
# [483] True=True → Pred=0
# 1
# [484] True=True → Pred=1
# 1
# [485] True=False → Pred=1
# 1
# [486] True=True → Pred=1
# 1
# [487] True=False → Pred=1
# 1
# [488] True=False → Pred=1
# 1
# [489] True=True → Pred=1
# 1
# [490] True=True → Pred=1
# 1
# [491] True=True → Pred=1
# 1
# [492] True=False → Pred=1
# 1
# [493] True=False → Pred=1
# 1
# [494] True=True → Pred=1
# 1
# [495] True=False → Pred=1
# 1
# [496] True=False → Pred=1
# 1
# [497] True=True → Pred=1
# 1
# [498] True=False → Pred=1
# 1
# [499] True=False → Pred=1
#
# 10-shot RAG→LLaVA accuracy: 55.2%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# If you have any None‐predictions, filter them out
valid_idx = [i for i, p in enumerate(preds) if p is not None]
y_true = [test_labels[i] for i in valid_idx]
y_pred = [preds[i]      for i in valid_idx]

# Compute metrics
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1-score : {f1:.4f}")
# Out:
# Accuracy : 0.5520
# Precision: 0.5440
# Recall   : 0.9963
# F1-score : 0.7037

# %%
alpha = 1.0          # weight for image
beta  = 1.0 - alpha  # weight for text
k     = 10

# %%
rag_results = []
for i in range(len(test_img_embs)):
    # weighted fusion
    q_img = test_img_embs[i] * alpha
    q_txt = test_txt_embs[i] * beta
    q = np.concatenate([q_img, q_txt], axis=0).reshape(1, -1)
    faiss.normalize_L2(q)

    # search
    D, I = index.search(q, k)
    neighs = []
    for score, idx in zip(D[0], I[0]):
        entry = docs[idx].copy()
        neighs.append({
            "id":      entry.get("id"),
            "caption": entry.get("caption"),
            "label":   entry.get("label"),
            "score":   float(score),
            # If you stored the combined embeddings you could also
            # reconstruct them here with index.reconstruct(idx)
        })
    rag_results.append(neighs)

print(f"Retrieved top-{k} neighbors for each of {len(rag_results)} test samples")
# Out:
# Retrieved top-10 neighbors for each of 500 test samples

# %%
preds = []
for i in range(len(test_images)):
    p = predict_with_few_shot(i)
    print(p)
    preds.append(int(p) if p.isdigit() else None)
    print(f"[{i}] True={test_labels[i]} → Pred={preds[-1]}")

acc = sum(p==t for p,t in zip(preds, test_labels)) / len(test_labels)
print(f"\n10-shot RAG→LLaVA accuracy: {acc:.1%}")
# Out:
# 0
# [0] True=False → Pred=0
# 1
# [1] True=True → Pred=1
# 0
# [2] True=False → Pred=0
# 1
# [3] True=True → Pred=1
# 0
# [4] True=True → Pred=0
# 1
# [5] True=False → Pred=1
# 1
# [6] True=True → Pred=1
# 1
# [7] True=True → Pred=1
# 1
# [8] True=True → Pred=1
# 0
# [9] True=False → Pred=0
# 0
# [10] True=True → Pred=0
# 1
# [11] True=False → Pred=1
# 1
# [12] True=True → Pred=1
# 1
# [13] True=True → Pred=1
# 0
# [14] True=False → Pred=0
# 0
# [15] True=True → Pred=0
# 1
# [16] True=False → Pred=1
# 1
# [17] True=True → Pred=1
# 1
# [18] True=True → Pred=1
# 0
# [19] True=True → Pred=0
# 1
# [20] True=True → Pred=1
# 0
# [21] True=False → Pred=0
# 0
# [22] True=False → Pred=0
# 0
# [23] True=False → Pred=0
# 0
# [24] True=False → Pred=0
# 0
# [25] True=True → Pred=0
# 1
# [26] True=True → Pred=1
# 1
# [27] True=False → Pred=1
# 1
# [28] True=True → Pred=1
# 1
# [29] True=True → Pred=1
# 0
# [30] True=True → Pred=0
# 0
# [31] True=True → Pred=0
# 1
# [32] True=True → Pred=1
# 1
# [33] True=True → Pred=1
# 1
# [34] True=True → Pred=1
# 1
# [35] True=True → Pred=1
# 0
# [36] True=True → Pred=0
# 1
# [37] True=False → Pred=1
# 1
# [38] True=True → Pred=1
# 0
# [39] True=True → Pred=0
# 1
# [40] True=True → Pred=1
# 1
# [41] True=True → Pred=1
# 0
# [42] True=False → Pred=0
# 0
# [43] True=False → Pred=0
# 1
# [44] True=True → Pred=1
# 1
# [45] True=False → Pred=1
# 1
# [46] True=True → Pred=1
# 1
# [47] True=True → Pred=1
# 1
# [48] True=True → Pred=1
# 1
# [49] True=True → Pred=1
# 1
# [50] True=True → Pred=1
# 1
# [51] True=True → Pred=1
# 1
# [52] True=True → Pred=1
# 1
# [53] True=True → Pred=1
# 1
# [54] True=False → Pred=1
# 1
# [55] True=True → Pred=1
# 1
# [56] True=True → Pred=1
# 1
# [57] True=True → Pred=1
# 1
# [58] True=False → Pred=1
# 1
# [59] True=False → Pred=1
# 0
# [60] True=True → Pred=0
# 1
# [61] True=True → Pred=1
# 0
# [62] True=False → Pred=0
# 1
# [63] True=True → Pred=1
# 0
# [64] True=False → Pred=0
# 0
# [65] True=True → Pred=0
# 1
# [66] True=True → Pred=1
# 1
# [67] True=False → Pred=1
# 1
# [68] True=True → Pred=1
# 1
# [69] True=True → Pred=1
# 1
# [70] True=True → Pred=1
# 1
# [71] True=False → Pred=1
# 1
# [72] True=False → Pred=1
# 0
# [73] True=False → Pred=0
# 1
# [74] True=True → Pred=1
# 1
# [75] True=True → Pred=1
# 1
# [76] True=True → Pred=1
# 1
# [77] True=True → Pred=1
# 1
# [78] True=True → Pred=1
# 1
# [79] True=True → Pred=1
# 1
# [80] True=True → Pred=1
# 0
# [81] True=False → Pred=0
# 1
# [82] True=True → Pred=1
# 1
# [83] True=True → Pred=1
# 1
# [84] True=True → Pred=1
# 1
# [85] True=True → Pred=1
# 0
# [86] True=True → Pred=0
# 1
# [87] True=False → Pred=1
# 1
# [88] True=True → Pred=1
# 1
# [89] True=True → Pred=1
# 1
# [90] True=True → Pred=1
# 1
# [91] True=True → Pred=1
# 1
# [92] True=True → Pred=1
# 1
# [93] True=True → Pred=1
# 0
# [94] True=False → Pred=0
# 1
# [95] True=True → Pred=1
# 1
# [96] True=True → Pred=1
# 0
# [97] True=True → Pred=0
# 1
# [98] True=True → Pred=1
# 1
# [99] True=False → Pred=1
# 1
# [100] True=True → Pred=1
# 1
# [101] True=False → Pred=1
# 1
# [102] True=True → Pred=1
# 0
# [103] True=False → Pred=0
# 1
# [104] True=True → Pred=1
# 0
# [105] True=False → Pred=0
# 1
# [106] True=True → Pred=1
# 0
# [107] True=False → Pred=0
# 1
# [108] True=False → Pred=1
# 1
# [109] True=True → Pred=1
# 1
# [110] True=True → Pred=1
# 1
# [111] True=True → Pred=1
# 1
# [112] True=True → Pred=1
# 1
# [113] True=True → Pred=1
# 1
# [114] True=True → Pred=1
# 1
# [115] True=False → Pred=1
# 1
# [116] True=False → Pred=1
# 0
# [117] True=False → Pred=0
# 1
# [118] True=False → Pred=1
# 1
# [119] True=True → Pred=1
# 1
# [120] True=True → Pred=1
# 0
# [121] True=False → Pred=0
# 1
# [122] True=True → Pred=1
# 1
# [123] True=True → Pred=1
# 0
# [124] True=False → Pred=0
# 1
# [125] True=True → Pred=1
# 1
# [126] True=True → Pred=1
# 1
# [127] True=True → Pred=1
# 0
# [128] True=False → Pred=0
# 1
# [129] True=False → Pred=1
# 1
# [130] True=True → Pred=1
# 1
# [131] True=True → Pred=1
# 1
# [132] True=True → Pred=1
# 1
# [133] True=False → Pred=1
# 1
# [134] True=True → Pred=1
# 1
# [135] True=False → Pred=1
# 1
# [136] True=False → Pred=1
# 1
# [137] True=True → Pred=1
# 0
# [138] True=False → Pred=0
# 1
# [139] True=True → Pred=1
# 1
# [140] True=True → Pred=1
# 1
# [141] True=True → Pred=1
# 1
# [142] True=True → Pred=1
# 1
# [143] True=False → Pred=1
# 1
# [144] True=True → Pred=1
# 0
# [145] True=False → Pred=0
# 1
# [146] True=False → Pred=1
# 0
# [147] True=False → Pred=0
# 0
# [148] True=False → Pred=0
# 1
# [149] True=False → Pred=1
# 1
# [150] True=False → Pred=1
# 0
# [151] True=False → Pred=0
# 1
# [152] True=True → Pred=1
# 0
# [153] True=False → Pred=0
# 1
# [154] True=False → Pred=1
# 0
# [155] True=False → Pred=0
# 0
# [156] True=False → Pred=0
# 1
# [157] True=True → Pred=1
# 0
# [158] True=True → Pred=0
# 0
# [159] True=False → Pred=0
# 0
# [160] True=False → Pred=0
# 0
# [161] True=False → Pred=0
# 1
# [162] True=False → Pred=1
# 0
# [163] True=False → Pred=0
# 0
# [164] True=False → Pred=0
# 1
# [165] True=False → Pred=1
# 1
# [166] True=False → Pred=1
# 0
# [167] True=False → Pred=0
# 1
# [168] True=False → Pred=1
# 0
# [169] True=False → Pred=0
# 1
# [170] True=True → Pred=1
# 0
# [171] True=False → Pred=0
# 1
# [172] True=False → Pred=1
# 0
# [173] True=False → Pred=0
# 1
# [174] True=True → Pred=1
# 1
# [175] True=False → Pred=1
# 1
# [176] True=True → Pred=1
# 1
# [177] True=True → Pred=1
# 1
# [178] True=True → Pred=1
# 0
# [179] True=True → Pred=0
# 1
# [180] True=False → Pred=1
# 1
# [181] True=True → Pred=1
# 1
# [182] True=True → Pred=1
# 0
# [183] True=False → Pred=0
# 1
# [184] True=False → Pred=1
# 0
# [185] True=True → Pred=0
# 0
# [186] True=False → Pred=0
# 0
# [187] True=False → Pred=0
# 1
# [188] True=False → Pred=1
# 0
# [189] True=False → Pred=0
# 0
# [190] True=False → Pred=0
# 1
# [191] True=True → Pred=1
# 0
# [192] True=False → Pred=0
# 1
# [193] True=False → Pred=1
# 1
# [194] True=False → Pred=1
# 1
# [195] True=True → Pred=1
# 0
# [196] True=False → Pred=0
# 0
# [197] True=False → Pred=0
# 1
# [198] True=True → Pred=1
# 1
# [199] True=True → Pred=1
# 1
# [200] True=False → Pred=1
# 1
# [201] True=False → Pred=1
# 0
# [202] True=False → Pred=0
# 0
# [203] True=False → Pred=0
# 0
# [204] True=False → Pred=0
# 0
# [205] True=True → Pred=0
# 1
# [206] True=True → Pred=1
# 0
# [207] True=False → Pred=0
# 1
# [208] True=True → Pred=1
# 1
# [209] True=True → Pred=1
# 1
# [210] True=True → Pred=1
# 0
# [211] True=True → Pred=0
# 0
# [212] True=True → Pred=0
# 1
# [213] True=True → Pred=1
# 1
# [214] True=False → Pred=1
# 0
# [215] True=True → Pred=0
# 0
# [216] True=False → Pred=0
# 0
# [217] True=True → Pred=0
# 1
# [218] True=True → Pred=1
# 1
# [219] True=True → Pred=1
# 1
# [220] True=True → Pred=1
# 0
# [221] True=False → Pred=0
# 0
# [222] True=False → Pred=0
# 1
# [223] True=True → Pred=1
# 0
# [224] True=False → Pred=0
# 1
# [225] True=True → Pred=1
# 0
# [226] True=True → Pred=0
# 1
# [227] True=True → Pred=1
# 0
# [228] True=False → Pred=0
# 1
# [229] True=True → Pred=1
# 1
# [230] True=True → Pred=1
# 1
# [231] True=False → Pred=1
# 1
# [232] True=True → Pred=1
# 1
# [233] True=False → Pred=1
# 0
# [234] True=False → Pred=0
# 0
# [235] True=False → Pred=0
# 0
# [236] True=True → Pred=0
# 1
# [237] True=True → Pred=1
# 1
# [238] True=True → Pred=1
# 1
# [239] True=True → Pred=1
# 1
# [240] True=True → Pred=1
# 1
# [241] True=True → Pred=1
# 1
# [242] True=False → Pred=1
# 0
# [243] True=False → Pred=0
# 0
# [244] True=False → Pred=0
# 0
# [245] True=False → Pred=0
# 0
# [246] True=False → Pred=0
# 1
# [247] True=True → Pred=1
# 1
# [248] True=True → Pred=1
# 0
# [249] True=False → Pred=0
# 1
# [250] True=True → Pred=1
# 1
# [251] True=True → Pred=1
# 0
# [252] True=False → Pred=0
# 1
# [253] True=True → Pred=1
# 0
# [254] True=False → Pred=0
# 1
# [255] True=True → Pred=1
# 0
# [256] True=False → Pred=0
# 0
# [257] True=False → Pred=0
# 0
# [258] True=False → Pred=0
# 0
# [259] True=True → Pred=0
# 1
# [260] True=True → Pred=1
# 1
# [261] True=True → Pred=1
# 1
# [262] True=True → Pred=1
# 0
# [263] True=False → Pred=0
# 0
# [264] True=False → Pred=0
# 1
# [265] True=False → Pred=1
# 1
# [266] True=True → Pred=1
# 0
# [267] True=False → Pred=0
# 0
# [268] True=False → Pred=0
# 1
# [269] True=True → Pred=1
# 1
# [270] True=True → Pred=1
# 0
# [271] True=False → Pred=0
# 0
# [272] True=False → Pred=0
# 0
# [273] True=False → Pred=0
# 0
# [274] True=False → Pred=0
# 1
# [275] True=False → Pred=1
# 0
# [276] True=False → Pred=0
# 0
# [277] True=False → Pred=0
# 1
# [278] True=False → Pred=1
# 1
# [279] True=False → Pred=1
# 0
# [280] True=False → Pred=0
# 1
# [281] True=True → Pred=1
# 1
# [282] True=True → Pred=1
# 1
# [283] True=False → Pred=1
# 0
# [284] True=False → Pred=0
# 1
# [285] True=True → Pred=1
# 1
# [286] True=False → Pred=1
# 1
# [287] True=False → Pred=1
# 0
# [288] True=False → Pred=0
# 0
# [289] True=False → Pred=0
# 1
# [290] True=False → Pred=1
# 1
# [291] True=True → Pred=1
# 0
# [292] True=True → Pred=0
# 0
# [293] True=True → Pred=0
# 1
# [294] True=False → Pred=1
# 0
# [295] True=True → Pred=0
# 1
# [296] True=True → Pred=1
# 0
# [297] True=False → Pred=0
# 0
# [298] True=False → Pred=0
# 0
# [299] True=True → Pred=0
# 1
# [300] True=False → Pred=1
# 0
# [301] True=False → Pred=0
# 1
# [302] True=False → Pred=1
# 1
# [303] True=True → Pred=1
# 1
# [304] True=True → Pred=1
# 0
# [305] True=False → Pred=0
# 1
# [306] True=False → Pred=1
# 1
# [307] True=True → Pred=1
# 0
# [308] True=False → Pred=0
# 0
# [309] True=False → Pred=0
# 1
# [310] True=False → Pred=1
# 1
# [311] True=False → Pred=1
# 1
# [312] True=True → Pred=1
# 1
# [313] True=True → Pred=1
# 1
# [314] True=False → Pred=1
# 0
# [315] True=False → Pred=0
# 1
# [316] True=False → Pred=1
# 1
# [317] True=False → Pred=1
# 0
# [318] True=False → Pred=0
# 1
# [319] True=True → Pred=1
# 1
# [320] True=True → Pred=1
# 0
# [321] True=True → Pred=0
# 0
# [322] True=False → Pred=0
# 1
# [323] True=False → Pred=1
# 1
# [324] True=True → Pred=1
# 1
# [325] True=False → Pred=1
# 1
# [326] True=False → Pred=1
# 1
# [327] True=True → Pred=1
# 1
# [328] True=True → Pred=1
# 1
# [329] True=False → Pred=1
# 0
# [330] True=False → Pred=0
# 1
# [331] True=True → Pred=1
# 1
# [332] True=False → Pred=1
# 0
# [333] True=False → Pred=0
# 1
# [334] True=False → Pred=1
# 0
# [335] True=False → Pred=0
# 1
# [336] True=True → Pred=1
# 1
# [337] True=False → Pred=1
# 1
# [338] True=True → Pred=1
# 0
# [339] True=True → Pred=0
# 0
# [340] True=False → Pred=0
# 0
# [341] True=False → Pred=0
# 1
# [342] True=True → Pred=1
# 1
# [343] True=False → Pred=1
# 1
# [344] True=True → Pred=1
# 0
# [345] True=False → Pred=0
# 0
# [346] True=False → Pred=0
# 1
# [347] True=False → Pred=1
# 0
# [348] True=True → Pred=0
# 1
# [349] True=True → Pred=1
# 1
# [350] True=False → Pred=1
# 1
# [351] True=False → Pred=1
# 1
# [352] True=True → Pred=1
# 1
# [353] True=True → Pred=1
# 1
# [354] True=True → Pred=1
# 1
# [355] True=False → Pred=1
# 1
# [356] True=True → Pred=1
# 1
# [357] True=True → Pred=1
# 0
# [358] True=False → Pred=0
# 1
# [359] True=False → Pred=1
# 1
# [360] True=False → Pred=1
# 1
# [361] True=False → Pred=1
# 0
# [362] True=False → Pred=0
# 1
# [363] True=True → Pred=1
# 1
# [364] True=True → Pred=1
# 0
# [365] True=False → Pred=0
# 0
# [366] True=False → Pred=0
# 0
# [367] True=True → Pred=0
# 0
# [368] True=False → Pred=0
# 1
# [369] True=True → Pred=1
# 1
# [370] True=True → Pred=1
# 0
# [371] True=False → Pred=0
# 0
# [372] True=True → Pred=0
# 1
# [373] True=True → Pred=1
# 1
# [374] True=True → Pred=1
# 1
# [375] True=False → Pred=1
# 0
# [376] True=False → Pred=0
# 1
# [377] True=True → Pred=1
# 0
# [378] True=False → Pred=0
# 1
# [379] True=True → Pred=1
# 0
# [380] True=False → Pred=0
# 0
# [381] True=False → Pred=0
# 1
# [382] True=True → Pred=1
# 0
# [383] True=True → Pred=0
# 1
# [384] True=True → Pred=1
# 1
# [385] True=True → Pred=1
# 1
# [386] True=True → Pred=1
# 1
# [387] True=True → Pred=1
# 1
# [388] True=True → Pred=1
# 1
# [389] True=True → Pred=1
# 1
# [390] True=True → Pred=1
# 0
# [391] True=False → Pred=0
# 0
# [392] True=False → Pred=0
# 0
# [393] True=False → Pred=0
# 0
# [394] True=True → Pred=0
# 0
# [395] True=False → Pred=0
# 1
# [396] True=False → Pred=1
# 0
# [397] True=False → Pred=0
# 1
# [398] True=True → Pred=1
# 1
# [399] True=True → Pred=1
# 1
# [400] True=True → Pred=1
# 0
# [401] True=False → Pred=0
# 1
# [402] True=False → Pred=1
# 0
# [403] True=True → Pred=0
# 1
# [404] True=True → Pred=1
# 1
# [405] True=False → Pred=1
# 1
# [406] True=False → Pred=1
# 1
# [407] True=True → Pred=1
# 0
# [408] True=False → Pred=0
# 1
# [409] True=True → Pred=1
# 0
# [410] True=True → Pred=0
# 1
# [411] True=True → Pred=1
# 1
# [412] True=False → Pred=1
# 0
# [413] True=True → Pred=0
# 1
# [414] True=False → Pred=1
# 1
# [415] True=True → Pred=1
# 0
# [416] True=False → Pred=0
# 1
# [417] True=False → Pred=1
# 0
# [418] True=False → Pred=0
# 0
# [419] True=False → Pred=0
# 1
# [420] True=True → Pred=1
# 1
# [421] True=False → Pred=1
# 1
# [422] True=False → Pred=1
# 1
# [423] True=True → Pred=1
# 1
# [424] True=True → Pred=1
# 1
# [425] True=True → Pred=1
# 1
# [426] True=False → Pred=1
# 0
# [427] True=True → Pred=0
# 0
# [428] True=False → Pred=0
# 0
# [429] True=True → Pred=0
# 1
# [430] True=True → Pred=1
# 1
# [431] True=True → Pred=1
# 0
# [432] True=False → Pred=0
# 0
# [433] True=False → Pred=0
# 1
# [434] True=True → Pred=1
# 1
# [435] True=True → Pred=1
# 1
# [436] True=True → Pred=1
# 1
# [437] True=True → Pred=1
# 1
# [438] True=True → Pred=1
# 1
# [439] True=False → Pred=1
# 1
# [440] True=True → Pred=1
# 0
# [441] True=True → Pred=0
# 1
# [442] True=True → Pred=1
# 0
# [443] True=False → Pred=0
# 0
# [444] True=False → Pred=0
# 1
# [445] True=True → Pred=1
# 1
# [446] True=False → Pred=1
# 1
# [447] True=True → Pred=1
# 0
# [448] True=False → Pred=0
# 1
# [449] True=True → Pred=1
# 0
# [450] True=False → Pred=0
# 0
# [451] True=True → Pred=0
# 1
# [452] True=True → Pred=1
# 1
# [453] True=True → Pred=1
# 1
# [454] True=True → Pred=1
# 1
# [455] True=True → Pred=1
# 1
# [456] True=True → Pred=1
# 1
# [457] True=True → Pred=1
# 1
# [458] True=True → Pred=1
# 1
# [459] True=True → Pred=1
# 1
# [460] True=False → Pred=1
# 0
# [461] True=False → Pred=0
# 1
# [462] True=True → Pred=1
# 1
# [463] True=True → Pred=1
# 1
# [464] True=True → Pred=1
# 0
# [465] True=False → Pred=0
# 1
# [466] True=True → Pred=1
# 1
# [467] True=True → Pred=1
# 1
# [468] True=True → Pred=1
# 1
# [469] True=True → Pred=1
# 0
# [470] True=True → Pred=0
# 1
# [471] True=True → Pred=1
# 1
# [472] True=True → Pred=1
# 1
# [473] True=False → Pred=1
# 1
# [474] True=True → Pred=1
# 0
# [475] True=True → Pred=0
# 1
# [476] True=True → Pred=1
# 0
# [477] True=False → Pred=0
# 1
# [478] True=False → Pred=1
# 0
# [479] True=False → Pred=0
# 0
# [480] True=False → Pred=0
# 0
# [481] True=False → Pred=0
# 1
# [482] True=True → Pred=1
# 1
# [483] True=True → Pred=1
# 1
# [484] True=True → Pred=1
# 0
# [485] True=False → Pred=0
# 0
# [486] True=True → Pred=0
# 1
# [487] True=False → Pred=1
# 0
# [488] True=False → Pred=0
# 1
# [489] True=True → Pred=1
# 1
# [490] True=True → Pred=1
# 1
# [491] True=True → Pred=1
# 1
# [492] True=False → Pred=1
# 1
# [493] True=False → Pred=1
# 1
# [494] True=True → Pred=1
# 0
# [495] True=False → Pred=0
# 1
# [496] True=False → Pred=1
# 1
# [497] True=True → Pred=1
# 1
# [498] True=False → Pred=1
# 1
# [499] True=False → Pred=1
#
# 10-shot RAG→LLaVA accuracy: 71.2%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# If you have any None‐predictions, filter them out
valid_idx = [i for i, p in enumerate(preds) if p is not None]
y_true = [test_labels[i] for i in valid_idx]
y_pred = [preds[i]      for i in valid_idx]

# Compute metrics
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1-score : {f1:.4f}")
# Out:
# Accuracy : 0.7120
# Precision: 0.6916
# Recall   : 0.8315
# F1-score : 0.7551
